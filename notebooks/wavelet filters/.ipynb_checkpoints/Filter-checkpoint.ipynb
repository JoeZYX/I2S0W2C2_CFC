# %% [markdown]
# # import package

# %%
import pywt
import matplotlib.pyplot as plt
import numpy as np
import scipy.fft as F
from sklearn.cluster import KMeans
import torch

# %% [markdown]
# # read all mother wavelets

# %%
motherwavelets = []

# %%
for family in pywt.families():
    for mother in pywt.wavelist(family):
        motherwavelets.append(mother)

# %%
print(motherwavelets)
# Out:
# ['haar', 'db1', 'db2', 'db3', 'db4', 'db5', 'db6', 'db7', 'db8', 'db9', 'db10', 'db11', 'db12', 'db13', 'db14', 'db15', 'db16', 'db17', 'db18', 'db19', 'db20', 'db21', 'db22', 'db23', 'db24', 'db25', 'db26', 'db27', 'db28', 'db29', 'db30', 'db31', 'db32', 'db33', 'db34', 'db35', 'db36', 'db37', 'db38', 'sym2', 'sym3', 'sym4', 'sym5', 'sym6', 'sym7', 'sym8', 'sym9', 'sym10', 'sym11', 'sym12', 'sym13', 'sym14', 'sym15', 'sym16', 'sym17', 'sym18', 'sym19', 'sym20', 'coif1', 'coif2', 'coif3', 'coif4', 'coif5', 'coif6', 'coif7', 'coif8', 'coif9', 'coif10', 'coif11', 'coif12', 'coif13', 'coif14', 'coif15', 'coif16', 'coif17', 'bior1.1', 'bior1.3', 'bior1.5', 'bior2.2', 'bior2.4', 'bior2.6', 'bior2.8', 'bior3.1', 'bior3.3', 'bior3.5', 'bior3.7', 'bior3.9', 'bior4.4', 'bior5.5', 'bior6.8', 'rbio1.1', 'rbio1.3', 'rbio1.5', 'rbio2.2', 'rbio2.4', 'rbio2.6', 'rbio2.8', 'rbio3.1', 'rbio3.3', 'rbio3.5', 'rbio3.7', 'rbio3.9', 'rbio4.4', 'rbio5.5', 'rbio6.8', 'dmey', 'gaus1', 'gaus2', 'gaus3', 'gaus4', 'gaus5', 'gaus6', 'gaus7', 'gaus8', 'mexh', 'morl', 'cgau1', 'cgau2', 'cgau3', 'cgau4', 'cgau5', 'cgau6', 'cgau7', 'cgau8', 'shan', 'fbsp', 'cmor']

# %%
len(motherwavelets)
# Out:
# 127

# %% [markdown]
# ## Visuialization of wavelets

# %%
fig, ax = plt.subplots(nrows = 18, ncols=6, figsize=(20, 50)) #

idx = 0
for i in range(18):
    for j in range(6):
        if idx < 127:
            mw_temp = motherwavelets[idx]
            if mw_temp.startswith('gaus') or mw_temp.startswith('mexh') or mw_temp.startswith('morl') or mw_temp.startswith('cmor') or mw_temp.startswith('fbsp') or mw_temp.startswith('shan') or mw_temp.startswith('cgau'):
                continue
            else:
                param = pywt.Wavelet(mw_temp).wavefun(level=5)
                psi, x = param[1], param[-1]

            idx += 1
            ax[i,j].plot(x, np.real(psi))
            ax[i,j].set_title(mw_temp)
            ax[i,j].set_xticks([],[])
plt.savefig(f'./figures for filter/1 mother wavelets.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# ## Uniform the dimensionality of all wavelets, e.g., normalization

# %%
X = np.zeros([1,128])
PSI = np.zeros([1,128])

fig, ax = plt.subplots(nrows = 18, ncols=6, figsize=(20, 50)) #

idx = 0
for i in range(36):
    for j in range(6):
        if idx < 127:
            mw_temp = motherwavelets[idx]
            if mw_temp.startswith('gaus') or mw_temp.startswith('mexh') or mw_temp.startswith('morl') or mw_temp.startswith('cmor') or mw_temp.startswith('fbsp') or mw_temp.startswith('shan') or mw_temp.startswith('cgau'):
                continue
            else:
                param = pywt.Wavelet(mw_temp).wavefun(level=7)
                psi, x = param[1], param[-1]
                
                idx_ds = np.round(np.linspace(0, x.shape[0]-1, 128)).astype(int)
                
                x = x[idx_ds]
                psi = psi[idx_ds]
                
                X = np.vstack((X, x.reshape(1,-1)))
                PSI = np.vstack((PSI, psi.reshape(1,-1)))

            idx += 1
            ax[i,j].plot(x, np.real(psi))
            ax[i,j].set_title(mw_temp)
            ax[i,j].set_xticks([],[])
# plt.savefig(f'./figures for filter/2 mother wavelets with down sampling.pdf', format='pdf', bbox_inches='tight')

X = X[1:,:]
PSI = PSI[1:,:]

# %% [markdown]
# # Wavelets clustering

# %%
K = 20

# %% [markdown]
# ## clustering by shape of wavelets

# %%
kmeans = KMeans(n_clusters=K, random_state=0).fit(PSI)

# %%
label = kmeans.labels_
label
# Out:
# array([ 3,  3, 12,  5, 17, 17, 11, 11, 11, 10, 10,  6,  6, 16, 16, 16,  7,
#         7,  7, 18,  1,  1,  1,  1,  1, 14, 14, 14, 18, 18, 18, 18, 18, 18,
#        14, 14, 14, 14,  1, 12,  5, 13,  4, 11,  6, 11,  6, 11, 16,  6, 10,
#         1, 16,  1, 18,  7,  1,  1, 13, 11, 11,  7,  7,  7,  7, 14, 14, 14,
#        14, 14, 14, 14, 14, 14, 14,  3,  9,  4,  5,  8,  6,  6,  2,  0, 19,
#        10, 10,  8,  8,  6,  3,  9,  4,  5,  8,  6,  6, 15,  9,  4,  4, 10,
#         8,  8,  6, 14], dtype=int32)

# %%
for k in range(K):
    wavesidxs = np.where(label==k)[0]
    n_row = np.ceil(len(wavesidxs)/6).astype(int)
    fig, ax = plt.subplots(nrows = n_row, ncols=6, figsize=(20, 20*n_row/6))
    i = 0
    j = 0
    for wavesidx in wavesidxs:
        x = X[wavesidx,:]
        psi = PSI[wavesidx,:]
        if n_row == 1:
            ax[j].plot(x, psi)
        else:
            ax[i,j].plot(x, psi)
            ax[i,j].set_xticks([],[])
        
        j += 1
        if j == 6:
            j = 0
            i += 1
#     plt.savefig(f'./figures for filter/3 grouped mothers by time/{k}-th group.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# ## clustering by shape + frequency

# %%
FRE = np.zeros([1,128])
for i in range(PSI.shape[0]):
    FRE = np.vstack((FRE, np.real(F.fft(PSI[i,:])).reshape(1,-1)))
FRE = FRE[1:,:]
PSI_extended = np.hstack((PSI, FRE))

# %%
kmeans = KMeans(n_clusters=K, random_state=0).fit(PSI_extended)

# %%
label = kmeans.labels_
label
# Out:
# array([ 9,  9,  3,  7,  4, 16, 10,  5,  5,  5, 10, 12,  8,  8,  8,  8, 12,
#         2,  2,  2,  2, 12, 18, 18, 18, 18, 18, 12, 12, 12, 12, 12, 12, 14,
#        14, 14, 14, 12, 12,  3,  7,  6, 16, 11,  1,  5, 12,  5,  8,  8,  2,
#         8,  8,  8,  2,  2,  8, 12,  6, 11,  5, 10,  2,  2,  2,  2, 14, 14,
#        14, 14, 14, 14, 14, 14, 14,  9, 10, 10, 19, 17,  1,  1,  0, 13,  5,
#         5, 15,  4,  1,  1,  9, 10, 10,  7,  4,  1,  1, 12, 10, 10, 10, 10,
#         4, 17,  1, 14], dtype=int32)

# %%
for k in range(K):
    wavesidxs = np.where(label==k)[0]
    n_row = np.ceil(len(wavesidxs)/6).astype(int)
    fig, ax = plt.subplots(nrows = n_row, ncols=6, figsize=(20, 20*n_row/6))
    i = 0
    j = 0
    for wavesidx in wavesidxs:
        x = X[wavesidx,:]
        psi = PSI[wavesidx,:]
        if n_row == 1:
            ax[j].plot(x, psi)
        else:
            ax[i,j].plot(x, psi)
            ax[i,j].set_xticks([],[])
        
        j += 1
        if j == 6:
            j = 0
            i += 1
#     plt.savefig(f'./figures for filter/4 grouped mothers by both/{k}-th group.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Summary of sec. 2 - sec. 3 in one function

# %%
def PrepareWavelets(K, length=20):
    motherwavelets = []
    for family in pywt.families():
        for mother in pywt.wavelist(family):
            motherwavelets.append(mother)
    
    X = np.zeros([1,length])
    PSI = np.zeros([1,length])
    for mw_temp in motherwavelets:
        if mw_temp.startswith('gaus') or mw_temp.startswith('mexh') or mw_temp.startswith('morl') or mw_temp.startswith('cmor') or mw_temp.startswith('fbsp') or mw_temp.startswith('shan') or mw_temp.startswith('cgau'):
            pass
        else:
            param = pywt.Wavelet(mw_temp).wavefun(level=7)
            psi, x = param[1], param[-1]

            # normalization
            psi_sum = np.sum(psi)
            if np.abs(psi_sum) > 1:
                psi = psi / np.abs(psi_sum)
            x = x / max(x)

            # down sampling
            idx_ds = np.round(np.linspace(0, x.shape[0]-1, length)).astype(int)
            x = x[idx_ds]
            psi = psi[idx_ds]

            X = np.vstack((X, x.reshape(1,-1)))
            PSI = np.vstack((PSI, psi.reshape(1,-1)))

    X = X[1:,:]
    PSI = PSI[1:,:]

    # clustering
    FRE = np.zeros([1,length])
    for i in range(PSI.shape[0]):
        FRE = np.vstack((FRE, np.real(F.fft(PSI[i,:])).reshape(1,-1)))
    FRE = FRE[1:,:]

    PSI_extended = np.hstack((PSI, FRE))
    kmeans = KMeans(n_clusters=K, random_state=0).fit(PSI_extended)
    label = kmeans.labels_

    SelectedWavelet = np.zeros([1,length])
    for k in range(K):
        wavesidx = np.where(label==k)[0][0]
        SelectedWavelet = np.vstack((SelectedWavelet, PSI[wavesidx,:]))            

    return torch.tensor(SelectedWavelet[1:,:])

# %%
SelectedWavelet = PrepareWavelets(K=10, length=129)
SelectedWavelet.shape
# Out:
# torch.Size([10, 129])

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(20, 10)) #

idx = 0
for i in range(2):
    for j in range(5):
        ax[i,j].plot(SelectedWavelet[idx,:])
        ax[i,j].set_xticks([],[])
        idx += 1

# %% [markdown]
# # Calculate wavelets from their mothers
#
# 1. zero padding
# 2. temporal compression $(t = 2t')$ and amplitude enlargement $(A' = 2A)$
# 3. formulation of dimensionality to `[n_filters, in_channel=1, H=1, W=windowsize]`

# %%
def FiltersExtention(Filters):
    K, WS = Filters.shape
    
    N_ds = int(torch.log2(torch.tensor(WS-1)).floor()) - 2
    N_padding = int((WS-1)/2)
    
    Filter_temp = Filters.repeat(N_ds,1,1)
    m = torch.nn.ConstantPad1d(N_padding, 0)
    
    for n_ds in range(N_ds-1):
        filter_temp = Filter_temp[n_ds,:,:]
        filter_temp_pad = m(filter_temp)
        filter_ds = filter_temp_pad[:,::2] #* 2.
        Filter_temp[n_ds+1,:,:] = filter_ds
    
    # formualte dimensionality
    Filter_temp = Filter_temp.view(K*N_ds,WS)
    Filter_temp = Filter_temp.repeat(1,1,1,1)
    Filter_temp = Filter_temp.permute(2,0,1,3)
    return Filter_temp

# %%
ScaledFilter = FiltersExtention(SelectedWavelet)

# %%
ScaledFilter.shape
# Out:
# torch.Size([50, 1, 1, 129])

# %% [markdown]
# ## Some visualization

# %%
plt.plot(ScaledFilter[7,0,0,:].numpy());

# %%
plt.plot(ScaledFilter[17,0,0,:].numpy());

# %%
plt.plot(ScaledFilter[27,0,0,:].numpy());

# %%
plt.plot(ScaledFilter[37,0,0,:].numpy());

# %%
plt.plot(ScaledFilter[47,0,0,:].numpy());

# %%
fig, ax = plt.subplots(nrows = 10, ncols=1, figsize=(20*0.618, 20)) #

for i in range(10):
    for j in range(5):
        ax[i].plot(ScaledFilter[10*(j-1)+i,0,0,:])
        ax[i].set_xticks([],[])
        ax[i].set_yticks([],[])
# plt.savefig(f'./figures for filter/5 scaled filters.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Formulate data
# 0. padding
# 1. Simulate the mini-batch
# 2. make the data in right form: `[n_batch, n_channel=1, H=n_sensors, W=WindowSize]`

# %%
data = np.loadtxt(f'./data_temp.txt')
data = torch.tensor(data)
data.shape
# Out:
# torch.Size([129, 6])

# %%
data = data.T
data.shape
# Out:
# torch.Size([6, 129])

# %%
plt.plot(data.T.numpy());

# %%
WS = 129

# %%
m = torch.nn.ReplicationPad1d(int((WS-1)/2))

# %%
data_padded = m(data)
data_padded.shape
# Out:
# torch.Size([6, 257])

# %%
plt.plot(data_padded.T.numpy());

# %%
data_padded = data_padded.repeat(3,1,1)[:,:,:,None]
data_padded.shape
# Out:
# torch.Size([3, 6, 257, 1])

# %%
data_padded = data_padded.permute([0,3,1,2])
data_padded.shape
# Out:
# torch.Size([3, 1, 6, 257])

# %% [markdown]
# # Filtering

# %%
RESULT = torch.nn.functional.conv2d(data_padded, ScaledFilter, padding='valid')

# %%
RESULT.shape
# Out:
# torch.Size([3, 50, 6, 129])

# %% [markdown]
# # Visualization

# %%
plt.plot(data[0,:].numpy());

# %%
plt.plot(RESULT[0,7,0,:].numpy());

# %%
plt.plot(RESULT[0,17,0,:].numpy());

# %%
plt.plot(RESULT[0,27,0,:].numpy());

# %%
plt.plot(RESULT[0,37,0,:].numpy());

# %%
plt.plot(RESULT[0,47,0,:].numpy());
