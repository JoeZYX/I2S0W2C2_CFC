# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch
import yaml
import os

# %% [markdown]
# # 参数设置

# %% [markdown]
# # 训练参数
# 除了路径 其他不要变

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   
# TODO change the path as relative path
args.to_save_path     = "../../../ISWC2022LearnableFilter/Run_logs"              
args.freq_save_path   = "../../../ISWC2022LearnableFilter/Freq_data"
args.window_save_path = "../../../ISWC2022LearnableFilter/Sliding_window"
args.root_path        = "../../../datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 256                                                    
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 150

args.learning_rate           = 0.001  
args.learning_rate_patience  = 5
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 15

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 3
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

# %% [markdown]
# ## 数据参数

# %%
args.data_name                        =  "pamap2"

args.wavelet_filtering                = False
args.wavelet_filtering_regularization = False
args.wavelet_filtering_finetuning     = False


args.difference       = False 
args.filtering        = False
args.magnitude        = False
args.weighted_sampler = False




args.pos_select       = None
args.sensor_select    = None


args.representation_type = "time"
args.exp_mode            = "LOCV"
if args.data_name      ==  "skodar":
    args.exp_mode            = "SOCV"

config_file = open('../../configs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
window_seconds       = config["window_seconds"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
args.c_in            = config["num_channels"]

if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.f_in            =  args.number_wavelet_filtering*N_ds+1
else:
    args.f_in            =  1

# %% [markdown]
# ## 模型参数

# %%
args.filter_scaling_factor = 1
args.model_type            = "deepconvlstm"

# %% [markdown]
# # 实验

# %%
for seed in [1,2,3,4,5]:
    args.seed = seed
    exp = Exp(args)
    exp.train()
# Out:
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  1
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88198758e-05 3.44234079e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================Skip the 0 CV Experiment================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.73566439e-05 3.61141206e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================Skip the 1 CV Experiment================
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [3.86100386e-05 3.89559797e-04]
# Train data number :  28467
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3163
# Test data number :  21440
# ================Skip the 2 CV Experiment================
# ================ the 3 th CV Experiment ================
# Leave one Out Experiment : The 4 Part as the test
# [-] Target sampling weights:  [3.95600918e-05 3.24569945e-04]
# Train data number :  28359
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3151
# Test data number :  22080
# ================Skip the 3 CV Experiment================
# ================ the 4 th CV Experiment ================
# Leave one Out Experiment : The 5 Part as the test
# [-] Target sampling weights:  [3.83420881e-05 4.46030330e-04]
# Train data number :  28323
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3147
# Test data number :  22294
# ================Skip the 4 CV Experiment================
# ================ the 5 th CV Experiment ================
# Leave one Out Experiment : The 6 Part as the test
# [-] Target sampling weights:  [3.89741991e-05 3.51493849e-04]
# Train data number :  28503
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3167
# Test data number :  21227
# ================Skip the 5 CV Experiment================
# ================ the 6 th CV Experiment ================
# Leave one Out Experiment : The 7 Part as the test
# [-] Target sampling weights:  [3.81271923e-05 3.37952011e-04]
# Train data number :  29187
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3243
# Test data number :  17173
# ================Skip the 6 CV Experiment================
# ================ the 7 th CV Experiment ================
# Leave one Out Experiment : The 8 Part as the test
# [-] Target sampling weights:  [3.57347055e-05 3.68324125e-04]
# Train data number :  30699
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3411
# Test data number :  8214
# ================Skip the 7 CV Experiment================
# ================ the 8 th CV Experiment ================
# Leave one Out Experiment : The 9 Part as the test
# [-] Target sampling weights:  [3.79650721e-05 3.82701875e-04]
# Train data number :  28953
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3217
# Test data number :  18560
# ================Skip the 8 CV Experiment================
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [4.00432467e-05 3.22788896e-04]
# Train data number :  28071
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3119
# Test data number :  23786
# ================Skip the 9 CV Experiment================
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  2
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88485296e-05 3.41997264e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================Skip the 0 CV Experiment================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.73636228e-05 3.60490267e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================Skip the 1 CV Experiment================
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [3.86548125e-05 3.85059684e-04]
# Train data number :  28467
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3163
# Test data number :  21440
# ================Skip the 2 CV Experiment================
# ================ the 3 th CV Experiment ================
# Leave one Out Experiment : The 4 Part as the test
# [-] Target sampling weights:  [3.96180817e-05 3.20718409e-04]
# Train data number :  28359
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3151
# Test data number :  22080
# ================Skip the 3 CV Experiment================
# ================ the 4 th CV Experiment ================
# Leave one Out Experiment : The 5 Part as the test
# [-] Target sampling weights:  [3.83567949e-05 4.44049734e-04]
# Train data number :  28323
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3147
# Test data number :  22294
# ================Skip the 4 CV Experiment================
# ================ the 5 th CV Experiment ================
# Leave one Out Experiment : The 6 Part as the test
# [-] Target sampling weights:  [3.90472472e-05 3.45661943e-04]
# Train data number :  28503
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3167
# Test data number :  21227
# ================Skip the 5 CV Experiment================
# ================ the 6 th CV Experiment ================
# Leave one Out Experiment : The 7 Part as the test
# [-] Target sampling weights:  [3.81606564e-05 3.35345406e-04]
# Train data number :  29187
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3243
# Test data number :  17173
# ================Skip the 6 CV Experiment================
# ================ the 7 th CV Experiment ================
# Leave one Out Experiment : The 8 Part as the test
# [-] Target sampling weights:  [3.57768953e-05 3.63901019e-04]
# Train data number :  30699
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3411
# Test data number :  8214
# ================Skip the 7 CV Experiment================
# ================ the 8 th CV Experiment ================
# Leave one Out Experiment : The 9 Part as the test
# [-] Target sampling weights:  [3.79794911e-05 3.81242852e-04]
# Train data number :  28953
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3217
# Test data number :  18560
# ================Skip the 8 CV Experiment================
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [4.00833734e-05 3.20204931e-04]
# Train data number :  28071
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3119
# Test data number :  23786
# ================Skip the 9 CV Experiment================
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  3
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88424937e-05 3.42465753e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================Skip the 0 CV Experiment================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.73817801e-05 3.58808755e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================Skip the 1 CV Experiment================
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [3.86234599e-05 3.88198758e-04]
# Train data number :  28467
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3163
# Test data number :  21440
# ================Skip the 2 CV Experiment================
# ================ the 3 th CV Experiment ================
# Leave one Out Experiment : The 4 Part as the test
# [-] Target sampling weights:  [3.96118043e-05 3.21130379e-04]
# Train data number :  28359
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3151
# Test data number :  22080
# ================Skip the 3 CV Experiment================
# ================ the 4 th CV Experiment ================
# Leave one Out Experiment : The 5 Part as the test
# [-] Target sampling weights:  [3.83553237e-05 4.44247001e-04]
# Train data number :  28323
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3147
# Test data number :  22294
# ================Skip the 4 CV Experiment================
# ================ the 5 th CV Experiment ================
# Leave one Out Experiment : The 6 Part as the test
# [-] Target sampling weights:  [3.89985181e-05 3.49528137e-04]
# Train data number :  28503
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3167
# Test data number :  21227
# ================Skip the 5 CV Experiment================
# ================ the 6 th CV Experiment ================
# Leave one Out Experiment : The 7 Part as the test
# [-] Target sampling weights:  [3.81490100e-05 3.36247478e-04]
# Train data number :  29187
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3243
# Test data number :  17173
# ================Skip the 6 CV Experiment================
# ================ the 7 th CV Experiment ================
# Leave one Out Experiment : The 8 Part as the test
# [-] Target sampling weights:  [3.57922617e-05 3.62318841e-04]
# Train data number :  30699
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3411
# Test data number :  8214
# ================Skip the 7 CV Experiment================
# ================ the 8 th CV Experiment ================
# Leave one Out Experiment : The 9 Part as the test
# [-] Target sampling weights:  [3.79780487e-05 3.81388253e-04]
# Train data number :  28953
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3217
# Test data number :  18560
# ================Skip the 8 CV Experiment================
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [4.00528698e-05 3.22164948e-04]
# Train data number :  28071
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3119
# Test data number :  23786
# ================Skip the 9 CV Experiment================
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  4
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88621172e-05 3.40947835e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================Skip the 0 CV Experiment================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.73817801e-05 3.58808755e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================Skip the 1 CV Experiment================
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [3.86473430e-05 3.85802469e-04]
# Train data number :  28467
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3163
# Test data number :  21440
# ================Skip the 2 CV Experiment================
# ================ the 3 th CV Experiment ================
# Leave one Out Experiment : The 4 Part as the test
# [-] Target sampling weights:  [3.95726157e-05 3.23729362e-04]
# Train data number :  28359
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3151
# Test data number :  22080
# ================Skip the 3 CV Experiment================
# ================ the 4 th CV Experiment ================
# Leave one Out Experiment : The 5 Part as the test
# [-] Target sampling weights:  [3.83759306e-05 4.41501104e-04]
# Train data number :  28323
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3147
# Test data number :  22294
# ================Skip the 4 CV Experiment================
# ================ the 5 th CV Experiment ================
# Leave one Out Experiment : The 6 Part as the test
# [-] Target sampling weights:  [3.90091672e-05 3.48675035e-04]
# Train data number :  28503
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3167
# Test data number :  21227
# ================Skip the 5 CV Experiment================
# ================ the 6 th CV Experiment ================
# Leave one Out Experiment : The 7 Part as the test
# [-] Target sampling weights:  [3.80952381e-05 3.40483487e-04]
# Train data number :  29187
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3243
# Test data number :  17173
# ================Skip the 6 CV Experiment================
# ================ the 7 th CV Experiment ================
# Leave one Out Experiment : The 8 Part as the test
# [-] Target sampling weights:  [3.57858574e-05 3.62976407e-04]
# Train data number :  30699
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3411
# Test data number :  8214
# ================Skip the 7 CV Experiment================
# ================ the 8 th CV Experiment ================
# Leave one Out Experiment : The 9 Part as the test
# [-] Target sampling weights:  [3.79766064e-05 3.81533766e-04]
# Train data number :  28953
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3217
# Test data number :  18560
# ================Skip the 8 CV Experiment================
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [4.00480577e-05 3.22476620e-04]
# Train data number :  28071
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3119
# Test data number :  23786
# ================Skip the 9 CV Experiment================
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  5
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88093298e-05 3.45065562e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================Skip the 0 CV Experiment================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.74027528e-05 3.56887937e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================Skip the 1 CV Experiment================
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [3.86922035e-05 3.81388253e-04]
# Train data number :  28467
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3163
# Test data number :  21440
# ================Skip the 2 CV Experiment================
# ================ the 3 th CV Experiment ================
# Leave one Out Experiment : The 4 Part as the test
# [-] Target sampling weights:  [3.96573604e-05 3.18167356e-04]
# Train data number :  28359
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3151
# Test data number :  22080
# ================Skip the 3 CV Experiment================
# ================ the 4 th CV Experiment ================
# Leave one Out Experiment : The 5 Part as the test
# [-] Target sampling weights:  [3.83980340e-05 4.38596491e-04]
# Train data number :  28323
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3147
# Test data number :  22294
# ================Skip the 4 CV Experiment================
# ================ the 5 th CV Experiment ================
# Leave one Out Experiment : The 6 Part as the test
# [-] Target sampling weights:  [3.90686045e-05 3.43997248e-04]
# Train data number :  28503
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3167
# Test data number :  21227
# ================Skip the 5 CV Experiment================
# ================ the 6 th CV Experiment ================
# Leave one Out Experiment : The 7 Part as the test
# [-] Target sampling weights:  [3.81664822e-05 3.34896182e-04]
# Train data number :  29187
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3243
# Test data number :  17173
# ================Skip the 6 CV Experiment================
# ================ the 7 th CV Experiment ================
# Leave one Out Experiment : The 8 Part as the test
# [-] Target sampling weights:  [3.57666583e-05 3.64963504e-04]
# Train data number :  30699
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3411
# Test data number :  8214
# ================Skip the 7 CV Experiment================
# ================ the 8 th CV Experiment ================
# Leave one Out Experiment : The 9 Part as the test
# [-] Target sampling weights:  [3.80083618e-05 3.78357927e-04]
# Train data number :  28953
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3217
# Test data number :  18560
# ================Skip the 8 CV Experiment================
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [4.01074881e-05 3.18674315e-04]
# Train data number :  28071
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3119
# Test data number :  23786
# ================Skip the 9 CV Experiment================
