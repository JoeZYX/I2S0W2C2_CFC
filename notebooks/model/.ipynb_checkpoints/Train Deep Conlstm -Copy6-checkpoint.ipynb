# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch
import yaml
import os

# %% [markdown]
# # 参数设置

# %% [markdown]
# # 训练参数
# 除了路径 其他不要变

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   
# TODO change the path as relative path
args.to_save_path     = "../../../ISWC2022LearnableFilter/Run_logs"              
args.freq_save_path   = "../../../ISWC2022LearnableFilter/Freq_data"
args.window_save_path = "../../../ISWC2022LearnableFilter/Sliding_window"
args.root_path        = "../../../datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 256                                                     
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 150

args.learning_rate           = 0.001  
args.learning_rate_patience  = 5
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 15

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 1
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

# %% [markdown]
# ## 数据参数

# %%
args.seed                             = 1


args.data_name                        =  "rw"

args.wavelet_filtering                = True
args.wavelet_filtering_regularization = True
args.wavelet_filtering_finetuning     = True
args.wavelet_filtering_finetuning_percent = 0.3

args.regulatization_tradeoff          = 0.0001
args.number_wavelet_filtering         = 10


args.difference       = False 
args.filtering        =  False
args.magnitude        =  False
args.weighted_sampler = False




args.pos_select       = None
args.sensor_select    = None


args.representation_type = "time"
args.exp_mode            = "LOCV"

config_file = open('../../configs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
window_seconds       = config["window_seconds"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
args.c_in            = config["num_channels"]

if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.f_in            =  args.number_wavelet_filtering*N_ds+1
else:
    args.f_in            =  1

# %% [markdown]
# ## 模型参数

# %%
args.filter_scaling_factor = 0.25
args.model_type            = "deepconvlstm"

# %% [markdown]
# # 实验

# %%
exp = Exp(args)
# Out:
# Use GPU: cuda:1
# Wavelet Filtering Regularization
# Build the DeepConvLSTM model!
# Done!
# Parameter : 1720571
# Set the seed as :  1

# %%
exp.train()
# Out:
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 15 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [0.00023935 0.00020614 0.00114025 0.00015751 0.00014501 0.00015934
#  0.00016038 0.00015716]
# Train data number :  42025
# The number of classes is :  8
# The input_length  is :  128
# The channel_in is :  21
# Validation data number :  4670
# Test data number :  17903
# ================Skip the 0 CV Experiment================
# ================Skip the 0 CV Experiment Fine Tuning================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [0.00024131 0.00019051 0.00113636 0.00015815 0.00014051 0.0001587
#  0.00015949 0.00015652]
# Train data number :  42673
# The number of classes is :  8
# The input_length  is :  128
# The channel_in is :  21
# Validation data number :  4742
# Test data number :  14069
# ================ Build the model ================
# Wavelet Filtering Regularization
# Build the DeepConvLSTM model!
# Epoch: 1 cost time: 127.07359004020691
# VALI: Epoch: 1, Steps: 334 | Train Loss: 0.3094040  Vali Loss: 0.1643344 Vali Accuracy: 0.9493884  Vali weighted F1: 0.9495404  Vali macro F1 0.9508153
# Validation loss decreased (inf --> 0.164334).  Saving model ...
# Epoch: 2 cost time: 123.59584760665894
# VALI: Epoch: 2, Steps: 334 | Train Loss: 0.1532407  Vali Loss: 0.1354022 Vali Accuracy: 0.9626740  Vali weighted F1: 0.9627575  Vali macro F1 0.9647885
# new best score!!!!
# Validation loss decreased (0.164334 --> 0.135402).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 123.55851078033447
# VALI: Epoch: 3, Steps: 334 | Train Loss: 0.1289681  Vali Loss: 0.1173186 Vali Accuracy: 0.9658372  Vali weighted F1: 0.9658766  Vali macro F1 0.9669014
# new best score!!!!
# Validation loss decreased (0.135402 --> 0.117319).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 125.13362574577332
# VALI: Epoch: 4, Steps: 334 | Train Loss: 0.1011664  Vali Loss: 0.0978680 Vali Accuracy: 0.9711092  Vali weighted F1: 0.9711723  Vali macro F1 0.9716590
# new best score!!!!
# Validation loss decreased (0.117319 --> 0.097868).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 124.31394982337952
# VALI: Epoch: 5, Steps: 334 | Train Loss: 0.0929949  Vali Loss: 0.0900065 Vali Accuracy: 0.9725854  Vali weighted F1: 0.9725862  Vali macro F1 0.9742396
# new best score!!!!
# Validation loss decreased (0.097868 --> 0.090006).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 124.46923828125
# VALI: Epoch: 6, Steps: 334 | Train Loss: 0.0828341  Vali Loss: 0.0817829 Vali Accuracy: 0.9730072  Vali weighted F1: 0.9730299  Vali macro F1 0.9737435
# new best score!!!!
# Validation loss decreased (0.090006 --> 0.081783).  Saving model ...
# new best score!!!!
# Epoch: 7 cost time: 124.70085835456848
# VALI: Epoch: 7, Steps: 334 | Train Loss: 0.0700600  Vali Loss: 0.1082430 Vali Accuracy: 0.9671025  Vali weighted F1: 0.9671433  Vali macro F1 0.9666082
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 8 cost time: 124.3406195640564
# VALI: Epoch: 8, Steps: 334 | Train Loss: 0.0630881  Vali Loss: 0.0665904 Vali Accuracy: 0.9782792  Vali weighted F1: 0.9782760  Vali macro F1 0.9776820
# new best score!!!!
# Validation loss decreased (0.081783 --> 0.066590).  Saving model ...
# new best score!!!!
# Epoch: 9 cost time:
# EarlyStopping counter: 13 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 58 cost time: 125.29777908325195
# VALI: Epoch: 58, Steps: 334 | Train Loss: 0.0041925  Vali Loss: 0.0214296 Vali Accuracy: 0.9943062  Vali weighted F1: 0.9943077  Vali macro F1 0.9947076
# EarlyStopping counter: 14 out of 15
# Learning rate adjusting counter: 4 out of 5
# Epoch: 59 cost time: 127.19730877876282
# VALI: Epoch: 59, Steps: 334 | Train Loss: 0.0044071  Vali Loss: 0.0214022 Vali Accuracy: 0.9943062  Vali weighted F1: 0.9943077  Vali macro F1 0.9947076
# EarlyStopping counter: 15 out of 15
# Early stopping
# Loading the best validation model!
# Final Test Performance : Test Accuracy: 0.9636790  Test weighted F1: 0.9722240  Test macro F1 0.8511685
# Wavelet Filtering Regularization
# Build the DeepConvLSTM model!
# Wavelet Filtering Regularization
# Build the DeepConvLSTM model!
# ------------Fine Tuning  :  36   will be pruned   -----------------------------------------
# old model Parameter : 1720571
# pruned model Parameter : 1709015
# ----------------------------------------------------------------------------------------
# Fine Tuning Epoch: 1 cost time: 134.69755172729492
# Fine Tuning VALI: Epoch: 1, Steps: 334 | Train Loss: 0.0065955  Vali Loss: 0.0237310 Vali Accuracy: 0.9936736  Vali weighted F1: 0.9936730  Vali macro F1 0.9942233
# Validation loss decreased (inf --> 0.023731).  Saving model ...
# Fine Tuning Epoch: 2 cost time: 132.8236472606659
# Fine Tuning VALI: Epoch: 2, Steps: 334 | Train Loss: 0.0041421  Vali Loss: 0.0238993 Vali Accuracy: 0.9930409  Vali weighted F1: 0.9930432  Vali macro F1 0.9935029
# EarlyStopping counter: 1 out of 5
# Learning rate adjusting counter: 2 out of 5
# Fine Tuning Epoch: 3 cost time: 132.60187792778015
# Fine Tuning VALI: Epoch: 3, Steps: 334 | Train Loss: 0.0034290  Vali Loss: 0.0217921 Vali Accuracy: 0.9945171  Vali weighted F1: 0.9945164  Vali macro F1 0.9949888
# new best score!!!!
# Validation loss decreased (0.023731 --> 0.021792).  Saving model ...
# new best score!!!!
# Fine Tuning Epoch: 4 cost time: 134.149071931839
# Fine Tuning VALI: Epoch: 4, Steps: 334 | Train Loss: 0.0031560  Vali Loss: 0.0233452 Vali Accuracy: 0.9945171  Vali weighted F1: 0.9945173  Vali macro F1 0.9949783
# EarlyStopping counter: 1 out of 5
# Learning rate adjusting counter: 1 out of 5
# Fine Tuning Epoch: 5 cost time: 139.2909116744995
# Fine Tuning VALI: Epoch: 5, Steps: 334 | Train Loss: 0.0024692  Vali Loss: 0.0214762 Vali Accuracy: 0.9943062  Vali weighted F1: 0.9943095  Vali macro F1 0.9947539
# new best score!!!!
# Validation loss decreased (0.021792 --> 0.021476).  Saving model ...
# new best score!!!!
# Fine Tuning Epoch: 6 cost time: 139.2133846282959
# Fine Tuning VALI: Epoch: 6, Steps: 334 | Train Loss: 0.0024200  Vali Loss: 0.0232102 Vali Accuracy: 0.9949388  Vali weighted F1: 0.9949383  Vali macro F1 0.9953017
# EarlyStopping counter: 1 out of 5
# Learning rate adjusting counter: 1 out of 5
# Fine Tuning Epoch: 7 cost time: 138.96424508094788
# Fine Tuning VALI: Epoch: 7, Steps: 334 | Train Loss: 0.0017171  Vali Loss: 0.0219127 Vali Accuracy: 0.9938844  Vali weighted F1: 0.9938829  Vali macro F1 0.9944385
# EarlyStopping counter: 2 out of 5
# Learning rate adjusting counter: 2 out of 5
# Fine Tuning Epoch: 8 cost time: 139.08177947998047
# Fine Tuning VALI: Epoch: 8, Steps: 334 | Train Loss: 0.0017346  Vali Loss: 0.0225465 Vali Accuracy: 0.9943062  Vali weighted F1: 0.9943082  Vali macro F1 0.9947361
# EarlyStopping counter: 3 out of 5
# Learning rate adjusting counter: 3 out of 5
# Fine Tuning Epoch: 9 cost time: 138.98960494995117
# Fine Tuning VALI: Epoch: 9, Steps: 334 | Train Loss: 0.0017638  Vali Loss: 0.0186705 Vali Accuracy: 0.9945171  Vali weighted F1: 0.9945177  Vali macro F1 0.9944822
# new best score!!!!
# Validation loss decreased (0.021476 --> 0.018671).  Saving model ...
# new best score!!!!
# Fine Tuning Epoch: 10 cost time: 138.84734463691711
# Fine Tuning VALI: Epoch: 10, Steps: 334 | Train Loss: 0.0017825  Vali Loss: 0.0213236 Vali Accuracy: 0.9951497  Vali weighted F1: 0.9951509  Vali macro F1 0.9955541
# EarlyStopping counter: 1 out of 5
# Learning rate adjusting counter: 1 out of 5
# Fine Tuning Epoch: 11 cost time: 138.40999817848206
# Fine Tuning VALI: Epoch: 11, Steps: 334 | Train Loss: 0.0016448  Vali Loss: 0.0211715 Vali Accuracy: 0.9949388  Vali weighted F1: 0.9949389  Vali macro F1 0.9953987
# EarlyStopping counter: 2 out of 5
# Learning rate adjusting counter: 2 out of 5
# Fine Tuning Epoch: 12 cost time: 138.01714324951172
# Fine Tuning VALI: Epoch: 12, Steps: 334 | Train Loss: 0.0012527  Vali Loss: 0.0186798 Vali Accuracy: 0.9945171  Vali weighted F1: 0.9945167  Vali macro F1 0.9949675
# EarlyStopping counter: 3 out of 5
# Learning rate adjusting counter: 3 out of 5
# Fine Tuning Epoch: 13 cost time: 138.03946328163147
# Fine Tuning VALI: Epoch: 13, Steps: 334 | Train Loss: 0.0011694  Vali Loss: 0.0206396 Vali Accuracy: 0.9949388  Vali weighted F1: 0.9949386  Vali macro F1 0.9955197
# EarlyStopping counter: 4 out of 5
# Learning rate adjusting counter: 4 out of 5
# Fine Tuning Epoch: 14 cost time: 138.09830713272095
# Fine Tuning VALI: Epoch: 14, Steps: 334 | Train Loss: 0.0011026  Vali Loss: 0.0208566 Vali Accuracy: 0.9943062  Vali weighted F1: 0.9943065  Vali macro F1 0.9948335
# EarlyStopping counter: 5 out of 5
# Early stopping
# Loading the best finetuned validation model!
# Fine Tuning Final Test Performance : Test Accuracy: 0.9414315  Test weighted F1: 0.9555312  Test macro F1 0.8382618
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [0.00024266 0.00020877 0.0011325  0.00015758 0.00014633 0.00015908
#  0.00016018 0.00015778]
# Train data number :  41841
# The number of classes is :  8
# The input_length  is :  128
# The channel_in is :  21
# Validation data number :  4649
# Test data number :  18998
# ================ Build the model ================
# Wavelet Filtering Regularization
# Build the DeepConvLSTM model!
# Epoch: 1 cost time: 124.84955978393555
# VALI: Epoch: 1, Steps: 327 | Train Loss: 0.2897617  Vali Loss: 0.1533002 Vali Accuracy: 0.9567649  Vali weighted F1: 0.9568595  Vali macro F1 0.9552599
# Validation loss decreased (inf --> 0.153300).  Saving model ...
# Epoch: 2 cost time: 120.82385444641113
# VALI: Epoch: 2, Steps: 327 | Train Loss: 0.1365988  Vali Loss: 0.1221363 Vali Accuracy: 0.9625726  Vali weighted F1: 0.9625335  Vali macro F1 0.9598775
# new best score!!!!
# Validation loss decreased (0.153300 --> 0.122136).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 116.04442167282104
# VALI: Epoch: 3, Steps: 327 | Train Loss: 0.1005635  Vali Loss: 0.0952031 Vali Accuracy: 0.9735427  Vali weighted F1: 0.9735570  Vali macro F1 0.9718502
# new best score!!!!
# Validation loss decreased (0.122136 --> 0.095203).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 115.74627041816711
# VALI: Epoch: 4, Steps: 327 | Train Loss: 0.0801302  Vali Loss: 0.0820237 Vali Accuracy: 0.9759088  Vali weighted F1: 0.9759630  Vali macro F1 0.9754173
# new best score!!!!
# Validation loss decreased (0.095203 --> 0.082024).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 115.3720703125
# VALI: Epoch: 5, Steps: 327 | Train Loss: 0.0628456  Vali Loss: 0.0710798 Vali Accuracy: 0.9795655  Vali weighted F1: 0.9795687  Vali macro F1 0.9785610
# new best score!!!!
# Validation loss decreased (0.082024 --> 0.071080).  Saving model ...
# new best score!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 exp.train()
#
# File /pfs/data5/home/kit/tm/px3192/I2S0W2C2_CFC/notebooks/model/../../experiment.py:219, in Exp.train(self)
#     216 self.model.train()
#     217 epoch_time = time.time()
# --> 219 for i, (batch_x1,batch_x2,batch_y) in enumerate(train_loader):
#     221     if "cross" in self.args.model_type:
#     222         batch_x1 = batch_x1.double().to(self.device)
#
# File ~/miniconda3/envs/SDIL/lib/python3.8/site-packages/torch/utils/data/dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     519 if self._sampler_iter is None:
#     520     self._reset()
# --> 521 data = self._next_data()
#     522 self._num_yielded += 1
#     523 if self._dataset_kind == _DatasetKind.Iterable and \
#     524         self._IterableDataset_len_called is not None and \
#     525         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/SDIL/lib/python3.8/site-packages/torch/utils/data/dataloader.py:561, in _SingleProcessDataLoaderIter._next_data(self)
#     559 def _next_data(self):
#     560     index = self._next_index()  # may raise StopIteration
# --> 561     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562     if self._pin_memory:
#     563         data = _utils.pin_memory.pin_memory(data)
#
# File ~/miniconda3/envs/SDIL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:44, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      42 def fetch(self, possibly_batched_index):
#      43     if self.auto_collation:
# ---> 44         data = [self.dataset[idx] for idx in possibly_batched_index]
#      45     else:
#      46         data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/SDIL/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:44, in <listcomp>(.0)
#      42 def fetch(self, possibly_batched_index):
#      43     if self.auto_collation:
# ---> 44         data = [self.dataset[idx] for idx in possibly_batched_index]
#      45     else:
#      46         data = self.dataset[possibly_batched_index]
#
# File /pfs/data5/home/kit/tm/px3192/I2S0W2C2_CFC/notebooks/model/../../dataloaders/__init__.py:166, in data_set.__getitem__(self, index)
#     164 data_x = data_x.repeat(1,1,1)[:,:,:,None]
#     165 data_x = data_x.permute([0,3,1,2])
# --> 166 data_x = torch.nn.functional.conv2d(data_x, self.ScaledFilter, padding='valid')[0,:,:,:self.args.windowsize]
#     168 data_x = data_x.permute(0,2,1)#.reshape(self.args.windowsize,-1)
#     169 sample_x = np.expand_dims(sample_x,0)
#
# KeyboardInterrupt:
