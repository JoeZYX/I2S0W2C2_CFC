# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch

import yaml
import os

# %% [markdown]
# # 参数设置

# %% [markdown]
# # 训练参数
# 除了路径 其他不要变

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   
# TODO change the path as relative path
args.to_save_path     = "../../../Run_logs"              
args.freq_save_path   = "../../../Freq_data"
args.window_save_path = "../../../Sliding_window"
args.root_path        = "../../../datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 256                                                     
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 150

args.learning_rate           = 0.001  
args.learning_rate_patience  = 5
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 15

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 2
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

# %% [markdown]
# ## 数据参数

# %%
args.seed                             = 1


args.data_name                        =  "hapt"

args.wavelet_filtering                = False
args.wavelet_filtering_regularization = False
args.wavelet_filtering_finetuning     = False
args.wavelet_filtering_finetuning_percent = 0.5
args.wavelet_filtering_learnable      = False
args.wavelet_filtering_layernorm      = False

args.regulatization_tradeoff          = 0
args.number_wavelet_filtering         = 6


args.difference       =  False 
args.filtering        =  False
args.magnitude        =  False
args.weighted_sampler =  False




args.pos_select       = None
args.sensor_select    = None


args.representation_type = "time"
args.exp_mode            = "LOCV"
if args.data_name      ==  "skodar":
    args.exp_mode            = "SOCV"
config_file = open('../../configs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
window_seconds       = config["window_seconds"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
args.c_in            = config["num_channels"]

if args.difference:
    args.c_in = args.c_in*2

if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.f_in            =  args.number_wavelet_filtering*N_ds+1
else:
    args.f_in            =  1

# %% [markdown]
# ## 模型参数

# %%
# args.filter_scaling_factor = 0.5
# args.model_type              = "deepconvlstm"#"tinyhar"#"sahar" #"deepconvlstm"

# # args.cross_channel_interaction_type = "attn"
# # args.cross_channel_aggregation_type = "filter"
# # args.temporal_info_interaction_type
# # args.temporal_info_aggregation_type

# %%
args.model_type              = "tinyhar"#"deepconvlstm"#"sahar" #"deepconvlstm"

args.cross_channel_interaction_type = "attn" # attn  transformer  identity
args.cross_channel_aggregation_type = "filter"   # filter  naive  FC
args.temporal_info_interaction_type = "attn"  # gru  lstm  attn  transformer  identity
args.temporal_info_aggregation_type = "naive"   # naive  filter  FC

# %% [markdown]
# # 实验

# %%
# 如果我们设置为 
# args.wavelet_filtering_learnable      = False
# exp = Exp(args)

# %%
# 如果我们设置为 
# args.wavelet_filtering_learnable      = True
# exp = Exp(args)

# %%
for seed in range(1,6):
    args.seed=seed
    exp = Exp(args)
    exp.train()
# Out:
# Use GPU: cuda:2
# Build the TinyHAR model!
# Done!
# Parameter : 54543
# Set the seed as :  1
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [0.000625   0.00062933 0.00068027 0.00057339 0.00051948 0.00053277
#  0.00714286 0.00934579 0.00609756 0.00704225 0.00555556 0.00724638]
# Train data number :  11076
# The number of classes is :  12
# The input_length  is :  128
# The channel_in is :  6
# Validation data number :  1231
# Test data number :  2322
# ================ Build the model ================
# Build the TinyHAR model!
# Epoch: 1 cost time: 3.940354347229004
# VALI: Epoch: 1, Steps: 44 | Train Loss: 1.5452118  Vali Loss: 1.0185364 Vali Accuracy: 0.7213647  Vali weighted F1: 0.6772991  Vali macro F1 0.3746982
# Validation loss decreased (inf --> 1.018536).  Saving model ...
# Epoch: 2 cost time: 3.880847692489624
# VALI: Epoch: 2, Steps: 44 | Train Loss: 0.7213795  Vali Loss: 0.5856966 Vali Accuracy: 0.8090983  Vali weighted F1: 0.7686973  Vali macro F1 0.4418588
# new best score!!!!
# Validation loss decreased (1.018536 --> 0.585697).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 3.873434066772461
# VALI: Epoch: 3, Steps: 44 | Train Loss: 0.4771586  Vali Loss: 0.4590841 Vali Accuracy: 0.8302193  Vali weighted F1: 0.8005575  Vali macro F1 0.4906006
# new best score!!!!
# Validation loss decreased (0.585697 --> 0.459084).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 3.878101110458374
# VALI: Epoch: 4, Steps: 44 | Train Loss: 0.3929604  Vali Loss: 0.4205777 Vali Accuracy: 0.8350934  Vali weighted F1: 0.8154313  Vali macro F1 0.5349784
# new best score!!!!
# Validation loss decreased (0.459084 --> 0.420578).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 3.899041175842285
# VALI: Epoch: 5, Steps: 44 | Train Loss: 0.3625211  Vali Loss: 0.3844944 Vali Accuracy: 0.8521527  Vali weighted F1: 0.8386176  Vali macro F1 0.5747679
# new best score!!!!
# Validation loss decreased (0.420578 --> 0.384494).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 3.870666742324829
# VALI: Epoch: 6, Steps: 44 | Train Loss: 0.3387084  Vali Loss: 0.3785037 Vali Accuracy: 0.8545898  Vali weighted F1: 0.8429450  Vali macro F1 0.6018265
# new best score!!!!
# Validation loss decreased (0.384494 --> 0.378504).  Saving model ...
# new best score!!!!
# Epoch: 7 cost time: 3.8716602325439453
# VALI: Epoch: 7, Steps: 44 | Train Loss: 0.3138735  Vali Loss: 0.3756996 Vali Accuracy: 0.8627132  Vali weighted F1: 0.8522748  Vali macro F1 0.6264752
# new best score!!!!
# Validation loss decreased (0.378504 --> 0.375700).  Saving model ...
# new best score!!!!
# Epoch: 8 cost time: 3.87835431098938
# VALI: Epoch: 8, Steps: 44 | Train Loss: 0.3066490  Vali Loss: 0.3590229 Vali Accuracy: 0.8667750  Vali weighted F1: 0.8587770  Vali macro F1 0.6263601
# new best score!!!!
# Validation loss decreased (0.375700 --> 0.359023).  Saving model ...
# new best score!!!!
# Epoch: 9 cost time: 3.795811653137207
# VALI: Epoch: 9, Steps: 44 | Train Loss: 0.2916949  Vali Loss: 0.3522668 Vali Accuracy: 0.8643379  Vali weighted F1: 0.8583219  Vali macro F1 0.6409051
# new best score!!!!
# Validation loss decreased (0.359023 --> 0.352267).  Saving model ...
# new best score!!!!
# Epoch: 10 cost time: 3.7151331901550293
# VALI: Epoch: 10, Steps: 44 | Train Loss: 0.2834414  Vali Loss: 0.3563114 Vali Accuracy: 0.8586515  Vali weighted F1: 0.8498729  Vali macro F1 0.6298939
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 11 cost time: 3.8110110759735107
# VALI: Epoch: 11, Steps: 44 | Train Loss: 0.2827183  Vali Loss: 0.3511354 Vali Accuracy: 0.8683997  Vali weighted F1: 0.8645214  Vali macro F1 0.6749165
# new best score!!!!
# Validation loss decreased (0.352267 --> 0.351135).  Saving model ...
# new best score!!!!
# Epoch: 12 cost time: 3.6892354488372803
# VALI: Epoch: 12, Steps: 44 | Train Loss: 0.2676535  Vali Loss: 0.3420207 Vali Accuracy: 0.8683997  Vali weighted F1: 0.8623126  Vali macro F1 0.6540824
# new best score!!!!
# Validation loss decreased (0.351135 --> 0.342021).  Saving model ...
# new best score!!!!
# Epoch: 13 cost time: 3.664034843444824
# VALI: Epoch: 13, Steps: 44 | Train Loss: 0.2642196  Vali Loss: 0.3425974 Vali Accuracy: 0.8708367  Vali weighted F1: 0.8673488  Vali macro F1 0.6683943
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 14 cost time: 3.7629401683807373
# VALI: Epoch: 14, Steps: 44 | Train Loss: 0.2602922  Vali Loss: 0.3492100 Vali Accuracy: 0.8692120  Vali weighted F1: 0.8640698  Vali macro F1 0.6776328
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 15 cost time: 3.6610047817230225
# VALI: Epoch: 15, Steps: 44 | Train Loss: 0.2520689  Vali Loss: 0.3723136 Vali Accuracy: 0.8602762  Vali weighted F1: 0.8533645  Vali macro F1 0.6591783
# EarlyStopping counter: 3 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 16 cost time: 3.945089340209961
# VALI: Epoch: 16, Steps: 44 | Train Loss: 0.2622196  Vali Loss: 0.3343143 Vali Accuracy: 0.8683997  Vali weighted F1: 0.8621013  Vali macro F1 0.6530331
# new best score!!!!
# Validation loss decreased (0.342021 --> 0.334314).  Saving model ...
# new best score!!!!
# Epoch: 17 cost time:
# ================ Build the model ================
# Build the TinyHAR model!
# Epoch: 1 cost time: 3.5781362056732178
# VALI: Epoch: 1, Steps: 41 | Train Loss: 1.5773014  Vali Loss: 1.0177839 Vali Accuracy: 0.6568712  Vali weighted F1: 0.5898693  Vali macro F1 0.3115079
# Validation loss decreased (inf --> 1.017784).  Saving model ...
# Epoch: 2 cost time: 3.5656003952026367
# VALI: Epoch: 2, Steps: 41 | Train Loss: 0.7612788  Vali Loss: 0.5814478 Vali Accuracy: 0.8081245  Vali weighted F1: 0.7716808  Vali macro F1 0.4223745
# new best score!!!!
# Validation loss decreased (1.017784 --> 0.581448).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 3.568115711212158
# VALI: Epoch: 3, Steps: 41 | Train Loss: 0.4631177  Vali Loss: 0.4386646 Vali Accuracy: 0.8366465  Vali weighted F1: 0.8197115  Vali macro F1 0.4938484
# new best score!!!!
# Validation loss decreased (0.581448 --> 0.438665).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 3.5572707653045654
# VALI: Epoch: 4, Steps: 41 | Train Loss: 0.3774637  Vali Loss: 0.3826385 Vali Accuracy: 0.8634399  Vali weighted F1: 0.8468600  Vali macro F1 0.5387495
# new best score!!!!
# Validation loss decreased (0.438665 --> 0.382639).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 3.553623914718628
# VALI: Epoch: 5, Steps: 41 | Train Loss: 0.3407257  Vali Loss: 0.3812565 Vali Accuracy: 0.8582541  Vali weighted F1: 0.8454931  Vali macro F1 0.5773039
# new best score!!!!
# Validation loss decreased (0.382639 --> 0.381256).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 3.5577878952026367
# VALI: Epoch: 6, Steps: 41 | Train Loss: 0.3189535  Vali Loss: 0.3975610 Vali Accuracy: 0.8634399  Vali weighted F1: 0.8592596  Vali macro F1 0.6163848
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 7 cost time: 3.551194429397583
# VALI: Epoch: 7, Steps: 41 | Train Loss: 0.3208118  Vali Loss: 0.3416668 Vali Accuracy: 0.8833189  Vali weighted F1: 0.8771344  Vali macro F1 0.6391440
# new best score!!!!
# Validation loss decreased (0.381256 --> 0.341667).  Saving model ...
# new best score!!!!
# Epoch: 8 cost time: 3.552753210067749
# VALI: Epoch: 8, Steps: 41 | Train Loss: 0.2922036  Vali Loss: 0.3430391 Vali Accuracy: 0.8833189  Vali weighted F1: 0.8782417  Vali macro F1 0.6646734
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 9 cost time: 3.548356056213379
# VALI: Epoch: 9, Steps: 41 | Train Loss: 0.2807841  Vali Loss: 0.3322282 Vali Accuracy: 0.8729473  Vali weighted F1: 0.8703894  Vali macro F1 0.6331429
# new best score!!!!
# Validation loss decreased (0.341667 --> 0.332228).  Saving model ...
# new best score!!!!
# Epoch: 10 cost time: 3.549844980239868
# VALI: Epoch: 10, Steps: 41 | Train Loss: 0.2805103  Vali Loss: 0.3550027 Vali Accuracy: 0.8712187  Vali weighted F1: 0.8661356  Vali macro F1 0.6523647
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 11 cost time: 3.553255558013916
# VALI: Epoch: 11, Steps: 41 | Train Loss: 0.2894752  Vali Loss: 0.3241893 Vali Accuracy: 0.8815903  Vali weighted F1: 0.8775042  Vali macro F1 0.6676016
# new best score!!!!
# Validation loss decreased (0.332228 --> 0.324189).  Saving model ...
# new best score!!!!
# Epoch: 12 cost time: 3.549543857574463
# VALI: Epoch: 12, Steps: 41 | Train Loss: 0.2584384  Vali Loss: 0.3108024 Vali Accuracy: 0.8902334  Vali weighted F1: 0.8863419  Vali macro F1 0.6716947
# new best score!!!!
# Validation loss decreased (0.324189 --> 0.310802).  Saving model ...
# new best score!!!!
# Epoch: 13 cost time:
  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 3.507143974304199
# VALI: Epoch: 3, Steps: 41 | Train Loss: 0.4628532  Vali Loss: 0.4056189 Vali Accuracy: 0.8522337  Vali weighted F1: 0.8319104  Vali macro F1 0.4910486
# new best score!!!!
# Validation loss decreased (0.539269 --> 0.405619).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 3.4982845783233643
# VALI: Epoch: 4, Steps: 41 | Train Loss: 0.3870972  Vali Loss: 0.3665708 Vali Accuracy: 0.8573883  Vali weighted F1: 0.8445447  Vali macro F1 0.5411616
# new best score!!!!
# Validation loss decreased (0.405619 --> 0.366571).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 3.462512254714966
# VALI: Epoch: 5, Steps: 41 | Train Loss: 0.3515222  Vali Loss: 0.3518980 Vali Accuracy: 0.8711340  Vali weighted F1: 0.8671516  Vali macro F1 0.5962690
# new best score!!!!
# Validation loss decreased (0.366571 --> 0.351898).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 3.5297460556030273
# VALI: Epoch: 6, Steps: 41 | Train Loss: 0.3331346  Vali Loss: 0.3660872 Vali Accuracy: 0.8668385  Vali weighted F1: 0.8596972  Vali macro F1 0.6002447
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 7 cost time: 3.4668707847595215
# VALI: Epoch: 7, Steps: 41 | Train Loss: 0.3162049  Vali Loss: 0.3411259 Vali Accuracy: 0.8762887  Vali weighted F1: 0.8712829  Vali macro F1 0.6337544
# new best score!!!!
# Validation loss decreased (0.351898 --> 0.341126).  Saving model ...
# new best score!!!!
# Epoch: 8 cost time: 3.460263729095459
# VALI: Epoch: 8, Steps: 41 | Train Loss: 0.3130446  Vali Loss: 0.3381150 Vali Accuracy: 0.8737113  Vali weighted F1: 0.8699923  Vali macro F1 0.6342368
# new best score!!!!
# Validation loss decreased (0.341126 --> 0.338115).  Saving model ...
# new best score!!!!
# Epoch: 9 cost time: 3.460951089859009
# VALI: Epoch: 9, Steps: 41 | Train Loss: 0.3018912  Vali Loss: 0.3380800 Vali Accuracy: 0.8702749  Vali weighted F1: 0.8664505  Vali macro F1 0.6502180
# new best score!!!!
# Validation loss decreased (0.338115 --> 0.338080).  Saving model ...
# new best score!!!!
# Epoch: 10 cost time: 3.4908533096313477
# VALI: Epoch: 10, Steps: 41 | Train Loss: 0.2927894  Vali Loss: 0.3630589 Vali Accuracy: 0.8676976  Vali weighted F1: 0.8634959  Vali macro F1 0.6410199
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 11 cost time: 3.4609861373901367
# VALI: Epoch: 11, Steps: 41 | Train Loss: 0.3005880  Vali Loss: 0.3064768 Vali Accuracy: 0.8848797  Vali weighted F1: 0.8817354  Vali macro F1 0.6908134
# new best score!!!!
# Validation loss decreased (0.338080 --> 0.306477).  Saving model ...
# new best score!!!!
# Epoch: 12 cost time: 3.625990390777588
# VALI: Epoch: 12, Steps: 41 | Train Loss: 0.2654254  Vali Loss: 0.2906202 Vali Accuracy: 0.8814433  Vali weighted F1: 0.8776303  Vali macro F1 0.6741741
# new best score!!!!
# Validation loss decreased (0.306477 --> 0.290620).  Saving model ...
# new best score!!!!
# Epoch: 13 cost time: 3.6877965927124023
# VALI: Epoch: 13, Steps: 41 | Train Loss: 0.2612666  Vali Loss: 0.2900247 Vali Accuracy: 0.8788660  Vali weighted F1: 0.8741224  Vali macro F1 0.6789345
# new best score!!!!
# Validation loss decreased (0.290620 --> 0.290025).  Saving model ...
# new best score!!!!
# Epoch: 14 cost time:
# EarlyStopping counter: 14 out of 15
# Learning rate adjusting counter: 4 out of 5
# Epoch: 103 cost time: 3.2460832595825195
# VALI: Epoch: 103, Steps: 40 | Train Loss: 0.2042262  Vali Loss: 0.2648103 Vali Accuracy: 0.9196823  Vali weighted F1: 0.9157491  Vali macro F1 0.6941808
# EarlyStopping counter: 15 out of 15
# Early stopping
# Loading the best validation model!
# Final Test Performance : Test Accuracy: 0.8428911  Test weighted F1: 0.8451786  Test macro F1 0.6450705
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [0.00064516 0.00068213 0.00074794 0.00062933 0.00057208 0.00058207
#  0.00763359 0.00980392 0.00649351 0.00714286 0.00537634 0.00735294]
# Train data number :  10257
# The number of classes is :  12
# The input_length  is :  128
# The channel_in is :  6
# Validation data number :  1140
# Test data number :  7165
# ================ Build the model ================
# Build the TinyHAR model!
# Epoch: 1 cost time: 3.311344623565674
# VALI: Epoch: 1, Steps: 41 | Train Loss: 2.1459765  Vali Loss: 1.8579881 Vali Accuracy: 0.5649123  Vali weighted F1: 0.4923960  Vali macro F1 0.2615188
# Validation loss decreased (inf --> 1.857988).  Saving model ...
# Epoch: 2 cost time: 3.3140337467193604
# VALI: Epoch: 2, Steps: 41 | Train Loss: 1.4620620  Vali Loss: 1.1102757 Vali Accuracy: 0.5745614  Vali weighted F1: 0.4970540  Vali macro F1 0.2624759
# new best score!!!!
# Validation loss decreased (1.857988 --> 1.110276).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 3.3334102630615234
# VALI: Epoch: 3, Steps: 41 | Train Loss: 1.0109560  Vali Loss: 0.9234340 Vali Accuracy: 0.6587719  Vali weighted F1: 0.5966874  Vali macro F1 0.3193616
# new best score!!!!
# Validation loss decreased (1.110276 --> 0.923434).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 3.3248414993286133
# VALI: Epoch: 4, Steps: 41 | Train Loss: 0.8662858  Vali Loss: 0.8306237 Vali Accuracy: 0.6807018  Vali weighted F1: 0.6169860  Vali macro F1 0.3308759
# new best score!!!!
# Validation loss decreased (0.923434 --> 0.830624).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 3.311035394668579
# VALI: Epoch: 5, Steps: 41 | Train Loss: 0.7643143  Vali Loss: 0.7605645 Vali Accuracy: 0.6964912  Vali weighted F1: 0.6563630  Vali macro F1 0.3541057
# new best score!!!!
# Validation loss decreased (0.830624 --> 0.760565).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 3.314690113067627
# VALI: Epoch: 6, Steps: 41 | Train Loss: 0.7002423  Vali Loss: 0.6496758 Vali Accuracy: 0.7333333  Vali weighted F1: 0.7007309  Vali macro F1 0.3946824
# new best score!!!!
# Validation loss decreased (0.760565 --> 0.649676).  Saving model ...
# new best score!!!!
# Epoch: 7 cost time: 3.3076975345611572
# VALI: Epoch: 7, Steps: 41 | Train Loss: 0.5978824  Vali Loss: 0.5480518 Vali Accuracy: 0.7947368  Vali weighted F1: 0.7642234  Vali macro F1 0.4388947
# new best score!!!!
# Validation loss decreased (0.649676 --> 0.548052).  Saving model ...
# new best score!!!!
# Epoch: 8 cost time: 3.3037376403808594
# VALI: Epoch: 8, Steps: 41 | Train Loss: 0.5026721  Vali Loss: 0.4797281 Vali Accuracy: 0.8096491  Vali weighted F1: 0.7844411  Vali macro F1 0.4673011
# new best score!!!!
# Validation loss decreased (0.548052 --> 0.479728).  Saving model ...
# new best score!!!!
# Epoch: 9 cost time: 3.3057167530059814
# VALI: Epoch: 9, Steps: 41 | Train Loss: 0.4688005  Vali Loss: 0.4755894 Vali Accuracy: 0.8131579  Vali weighted F1: 0.7925589  Vali macro F1 0.4665148
# new best score!!!!
# Validation loss decreased (0.479728 --> 0.475589).  Saving model ...
# new best score!!!!
# Epoch: 10 cost time: 3.3029544353485107
# VALI: Epoch: 10, Steps: 41 | Train Loss: 0.4274746  Vali Loss: 0.4155121 Vali Accuracy: 0.8254386  Vali weighted F1: 0.8083624  Vali macro F1 0.4947790
# new best score!!!!
# Validation loss decreased (0.475589 --> 0.415512).  Saving model ...
# new best score!!!!
# Epoch: 11 cost time: 3.3022894859313965
# VALI: Epoch: 11, Steps: 41 | Train Loss: 0.3965013  Vali Loss: 0.4005748 Vali Accuracy: 0.8412281  Vali weighted F1: 0.8283833  Vali macro F1 0.5052425
# new best score!!!!
# Validation loss decreased (0.415512 --> 0.400575).  Saving model ...
# new best score!!!!
# Epoch: 12 cost time: 3.3052303791046143
# VALI: Epoch: 12, Steps: 41 | Train Loss: 0.3891295  Vali Loss: 0.4219077 Vali Accuracy: 0.8394737  Vali weighted F1: 0.8276205  Vali macro F1 0.5348469
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 13 cost time: 3.3102641105651855
# VALI: Epoch: 13, Steps: 41 | Train Loss: 0.3853536  Vali Loss: 0.4344788 Vali Accuracy: 0.8394737  Vali weighted F1: 0.8265120  Vali macro F1 0.5351131
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
#       2 args.seed=seed
#       3 exp = Exp(args)
# ----> 4 exp.train()
#
# File /pfs/data5/home/kit/tm/px6680/ISWC 2022/lightweightHAR/I2S0W2C2_CFC/notebooks/model/../../experiment.py:280, in Exp.train(self)
#     277 self.model.train()
#     278 epoch_time = time.time()
# --> 280 for i, (batch_x1,batch_x2,batch_y) in enumerate(train_loader):
#     281
#     282     #if "cross" in self.args.model_type:
#     283     #    batch_x1 = batch_x1.double().to(self.device)
#     284     #    batch_x2 = batch_x2.double().to(self.device)
#     285     #    batch_y = batch_y.long().to(self.device)
#     286     #    # model prediction
#     287     #    if self.args.output_attention:
#     288     #        outputs = self.model(batch_x1,batch_x2)[0]
#     289     #    else:
#     290     #        outputs = self.model(batch_x1,batch_x2)
#     291     #else:
#     292     batch_x1 = batch_x1.double().to(self.device) #--
#     293     batch_y = batch_y.long().to(self.device) #--
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     519 if self._sampler_iter is None:
#     520     self._reset()
# --> 521 data = self._next_data()
#     522 self._num_yielded += 1
#     523 if self._dataset_kind == _DatasetKind.Iterable and \
#     524         self._IterableDataset_len_called is not None and \
#     525         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:561, in _SingleProcessDataLoaderIter._next_data(self)
#     559 def _next_data(self):
#     560     index = self._next_index()  # may raise StopIteration
# --> 561     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562     if self._pin_memory:
#     563         data = _utils.pin_memory.pin_memory(data)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:44, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      42 def fetch(self, possibly_batched_index):
#      43     if self.auto_collation:
# ---> 44         data = [self.dataset[idx] for idx in possibly_batched_index]
#      45     else:
#      46         data = self.dataset[possibly_batched_index]
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:44, in <listcomp>(.0)
#      42 def fetch(self, possibly_batched_index):
#      43     if self.auto_collation:
# ---> 44         data = [self.dataset[idx] for idx in possibly_batched_index]
#      45     else:
#      46         data = self.dataset[possibly_batched_index]
#
# File /pfs/data5/home/kit/tm/px6680/ISWC 2022/lightweightHAR/I2S0W2C2_CFC/notebooks/model/../../dataloaders/__init__.py:168, in data_set.__getitem__(self, index)
#     165 else:
#     166     sample_x = self.data_x.iloc[start_index:end_index, 1:-1].values
# --> 168 sample_y = self.class_transform[self.data_y.iloc[start_index:end_index].mode().loc[0]]
#     169 #print(sample_x.shape)
#     172 sample_x = np.expand_dims(sample_x,0)
#
# File /opt/bwhpc/common/jupyter/tensorflow/2022-03-30/lib/python3.8/site-packages/pandas/core/series.py:2026, in Series.mode(self, dropna)
#    2023     res_values = values._mode(dropna=dropna)
#    2025 # Ensure index is type stable (should always use int index)
# -> 2026 return self._constructor(
#    2027     res_values, index=range(len(res_values)), name=self.name
#    2028 )
#
# File /opt/bwhpc/common/jupyter/tensorflow/2022-03-30/lib/python3.8/site-packages/pandas/core/series.py:460, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     457             data = SingleArrayManager.from_array(data, index)
#     459 NDFrame.__init__(self, data)
# --> 460 self.name = name
#     461 self._set_axis(0, index, fastpath=True)
#
# File /opt/bwhpc/common/jupyter/tensorflow/2022-03-30/lib/python3.8/site-packages/pandas/core/generic.py:5605, in NDFrame.__setattr__(self, name, value)
#    5603     object.__setattr__(self, name, value)
#    5604 elif name in self._metadata:
# -> 5605     object.__setattr__(self, name, value)
#    5606 else:
#    5607     try:
#
# File /opt/bwhpc/common/jupyter/tensorflow/2022-03-30/lib/python3.8/site-packages/pandas/core/series.py:640, in Series.name(self, value)
#     592     """
#     593     Return the name of the Series.
#     594
#    (...)
#     636     'Even Numbers'
#     637     """
#     638     return self._name
# --> 640 @name.setter
#     641 def name(self, value: Hashable) -> None:
#     642     validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     643     object.__setattr__(self, "_name", value)
#
# KeyboardInterrupt:

# %%
dataset = data_dict[args.data_name](args)
# Out:
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------

# %%
import numpy as np

# %%
start_index = dataset.train_slidingwindows[0][1]
end_index   = dataset.train_slidingwindows[0][2]
sample_x_1    = dataset.data_x.iloc[start_index:end_index, 1:-1].values

start_index = dataset.train_slidingwindows[100][1]
end_index   = dataset.train_slidingwindows[100][2]
sample_x_2    = dataset.data_x.iloc[start_index:end_index, 1:-1].values

temp_1 = np.expand_dims(sample_x_1,0)
temp_2 = np.expand_dims(sample_x_2,0)
combined_x = np.concatenate([temp_1,temp_2],axis=0)
combined_x = np.expand_dims(combined_x,1)
combined_x = torch.tensor(combined_x).double().to(exp.device)
print(combined_x.shape)
# Out:
# torch.Size([2, 1, 128, 6])

# %%
out = exp.model(combined_x)
out = out.cpu().detach().numpy()

# %%
out.shape
# Out:
# (2, 31, 128, 6)

# %%
weight = exp.model.wave_conv.wavelet_conv.weight.cpu().detach().numpy()

# %%
for n,p in exp.model.named_parameters():
    print(n)
# Out:
# gamma
# wave_conv.wavelet_conv.weight

# %%
import matplotlib.pyplot as plt
index1 = 0
index2 = 0

plt.figure()
plt.plot(out[0,0,:,index2])
plt.plot(out[0,1,:,index2])
plt.plot(out[0,2,:,index2])
plt.plot(out[0,3,:,index2])

# %%
# 如果我们设置为 
# args.wavelet_filtering_learnable      = True
# exp = Exp(args)
