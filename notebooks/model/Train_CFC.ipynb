# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch
import yaml
import os

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   

args.to_save_path     = r"E:\TECO_Works\Conference\ISWC2022\Run_logs"              
args.freq_save_path   = r"E:\TECO_Works\Conference\ISWC2022\Freq_data"
args.window_save_path = r"E:\TECO_Works\Conference\ISWC2022\Sliding_window"
args.root_path        = r"E:\datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 128                                                     
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 75

args.learning_rate           = 0.001  
args.learning_rate_patience  = 4
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 12

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 0
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

args.model_type = "cfc"

# %%
args.data_name        =  "hapt"
args.difference       = False 
args.filtering        =  False
args.magnitude        =  False
args.weighted_sampler = False


args.wavelet_filtering        = True
args.number_wavelet_filtering = 10


args.pos_select       = None
args.sensor_select    = None

window_seconds        = 2.56
args.representation_type = "time"
args.exp_mode            = "LOCV"

config_file = open('../../dataconfigs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.c_in            =  config["num_channels"]*args.number_wavelet_filtering*N_ds
else:
    args.c_in            =  config["num_channels"]

# %%
exp = Exp(args)
exp.train()
# Out:
# Use GPU: cuda:0
# Build the CFC model!
# Done!
# Parameter : 83197
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ Build the model ================
# Build the CFC model!
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [0.00067295 0.00067705 0.00073046 0.00061162 0.00056433 0.00057045
#  0.0075188  0.01010101 0.00621118 0.00729927 0.00558659 0.00724638]
# Train data number :  10339
# The number of classes is :  12
# The input_length  is :  128
# The channel_in is :  6
# Validation data number :  1149
# Test data number :  6632
# Epoch: 1 cost time: 34.60817503929138
# VALI: Epoch: 1, Steps: 81 | Train Loss: 0.8599955  Vali Loss: 0.4075946 Vali Accuracy: 0.8633594  Vali weighted F1: 0.8566926  Vali macro F1 0.5797371
# Validation loss decreased (inf --> 0.407595).  Saving model ...
# Epoch: 2 cost time: 33.266499042510986
# VALI: Epoch: 2, Steps: 81 | Train Loss: 0.3031774  Vali Loss: 0.2398388 Vali Accuracy: 0.9147084  Vali weighted F1: 0.9122597  Vali macro F1 0.7007772
# new best score!!!!
# Validation loss decreased (0.407595 --> 0.239839).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 33.42253398895264
# VALI: Epoch: 3, Steps: 81 | Train Loss: 0.2112071  Vali Loss: 0.2223715 Vali Accuracy: 0.9225413  Vali weighted F1: 0.9205524  Vali macro F1 0.7458025
# new best score!!!!
# Validation loss decreased (0.239839 --> 0.222371).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 33.79706430435181
# VALI: Epoch: 4, Steps: 81 | Train Loss: 0.1764799  Vali Loss: 0.1524810 Vali Accuracy: 0.9399478  Vali weighted F1: 0.9402768  Vali macro F1 0.8018140
# new best score!!!!
# Validation loss decreased (0.222371 --> 0.152481).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 33.62657976150513
# VALI: Epoch: 5, Steps: 81 | Train Loss: 0.1651032  Vali Loss: 0.1626220 Vali Accuracy: 0.9416884  Vali weighted F1: 0.9419366  Vali macro F1 0.8282383
# EarlyStopping counter: 1 out of 12
# Learning rate adjusting counter: 1 out of 4
# Epoch: 6 cost time: 34.001495599746704
# VALI: Epoch: 6, Steps: 81 | Train Loss: 0.1380855  Vali Loss: 0.1510953 Vali Accuracy: 0.9408181  Vali weighted F1: 0.9400389  Vali macro F1 0.7799420
# new best score!!!!
# Validation loss decreased (0.152481 --> 0.151095).  Saving model ...
# new best score!!!!
