# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append("../../")

from experiment import Exp

from dataloaders import data_set,data_dict
import torch
import yaml
import os

# %% [markdown]
# # 参数设置

# %% [markdown]
# # 训练参数
# 除了路径 其他不要变

# %%
class dotdict(dict):
    """dot.notation access to dictionary attributes"""
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

args = dotdict()   
# TODO change the path as relative path
args.to_save_path     = "../../../ISWC2022LearnableFilter/Run_logs"              
args.freq_save_path   = "../../../ISWC2022LearnableFilter/Freq_data"
args.window_save_path = "../../../ISWC2022LearnableFilter/Sliding_window"
args.root_path        = "../../../datasets"


args.drop_transition  = False
args.datanorm_type    = "standardization" # None ,"standardization", "minmax"


args.batch_size       = 256                                                    
args.shuffle          = True
args.drop_last        = False
args.train_vali_quote = 0.90                                           


# training setting 
args.train_epochs            = 150

args.learning_rate           = 0.001  
args.learning_rate_patience  = 5
args.learning_rate_factor    = 0.1


args.early_stop_patience     = 15

args.use_gpu                 = True if torch.cuda.is_available() else False
args.gpu                     = 3
args.use_multi_gpu           = False

args.optimizer               = "Adam"
args.criterion               = "CrossEntropy"

# %% [markdown]
# ## 数据参数

# %%
args.data_name                        =  "dg"

args.wavelet_filtering                = False
args.wavelet_filtering_regularization = False
args.wavelet_filtering_finetuning     = False


args.difference       = False 
args.filtering        = False
args.magnitude        = False
args.weighted_sampler = False




args.pos_select       = None
args.sensor_select    = None


args.representation_type = "time"
args.exp_mode            = "LOCV"
if args.data_name      ==  "skodar":
    args.exp_mode            = "SOCV"

config_file = open('../../configs/data.yaml', mode='r')
data_config = yaml.load(config_file, Loader=yaml.FullLoader)
config = data_config[args.data_name]

args.root_path       = os.path.join(args.root_path,config["filename"])
args.sampling_freq   = config["sampling_freq"]
args.num_classes     =  config["num_classes"]
window_seconds       = config["window_seconds"]
args.windowsize      =   int(window_seconds * args.sampling_freq) 
args.input_length    =  args.windowsize
# input information
args.c_in            = config["num_channels"]

if args.wavelet_filtering :
    
    if args.windowsize%2==1:
        N_ds = int(torch.log2(torch.tensor(args.windowsize-1)).floor()) - 2
    else:
        N_ds = int(torch.log2(torch.tensor(args.windowsize)).floor()) - 2

    args.f_in            =  args.number_wavelet_filtering*N_ds+1
else:
    args.f_in            =  1

# %% [markdown]
# ## 模型参数

# %%
args.filter_scaling_factor = 1
args.model_type            = "deepconvlstm"

# %% [markdown]
# # 实验

# %%
for seed in [1,2,3,4,5]:
    args.seed = seed
    exp = Exp(args)
    exp.train()
# Out:
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  1
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88198758e-05 3.44234079e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================Skip the 0 CV Experiment================
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.73566439e-05 3.61141206e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================Skip the 1 CV Experiment================
# ================ the 2 th CV Experiment ================
# Leave one Out Experiment : The 3 Part as the test
# [-] Target sampling weights:  [3.86100386e-05 3.89559797e-04]
# Train data number :  28467
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3163
# Test data number :  21440
# ================Skip the 2 CV Experiment================
# ================ the 3 th CV Experiment ================
# Leave one Out Experiment : The 4 Part as the test
# [-] Target sampling weights:  [3.95600918e-05 3.24569945e-04]
# Train data number :  28359
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3151
# Test data number :  22080
# ================Skip the 3 CV Experiment================
# ================ the 4 th CV Experiment ================
# Leave one Out Experiment : The 5 Part as the test
# [-] Target sampling weights:  [3.83420881e-05 4.46030330e-04]
# Train data number :  28323
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3147
# Test data number :  22294
# ================Skip the 4 CV Experiment================
# ================ the 5 th CV Experiment ================
# Leave one Out Experiment : The 6 Part as the test
# [-] Target sampling weights:  [3.89741991e-05 3.51493849e-04]
# Train data number :  28503
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3167
# Test data number :  21227
# ================Skip the 5 CV Experiment================
# ================ the 6 th CV Experiment ================
# Leave one Out Experiment : The 7 Part as the test
# [-] Target sampling weights:  [3.81271923e-05 3.37952011e-04]
# Train data number :  29187
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3243
# Test data number :  17173
# ================Skip the 6 CV Experiment================
# ================ the 7 th CV Experiment ================
# Leave one Out Experiment : The 8 Part as the test
# [-] Target sampling weights:  [3.57347055e-05 3.68324125e-04]
# Train data number :  30699
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3411
# Test data number :  8214
# ================Skip the 7 CV Experiment================
# ================ the 8 th CV Experiment ================
# Leave one Out Experiment : The 9 Part as the test
# [-] Target sampling weights:  [3.79650721e-05 3.82701875e-04]
# Train data number :  28953
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3217
# Test data number :  18560
# ================Skip the 8 CV Experiment================
# ================ the 9 th CV Experiment ================
# Leave one Out Experiment : The 10 Part as the test
# [-] Target sampling weights:  [4.00432467e-05 3.22788896e-04]
# Train data number :  28071
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3119
# Test data number :  23786
# ================Skip the 9 CV Experiment================
# Use GPU: cuda:3
# Build the DeepConvLSTM model!
# Done!
# Parameter : 423746
# Set the seed as :  2
#  ----------------------- load all the data -------------------
# -----------------------Sliding file are generated -----------------------
# -----------------------Sliding file are generated -----------------------
# ================ LOCV Mode ====================
# ================ 10 CV ======================
# ================ the 0 th CV Experiment ================
# Leave one Out Experiment : The 1 Part as the test
# [-] Target sampling weights:  [3.88485296e-05 3.41997264e-04]
# Train data number :  28665
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3185
# Test data number :  20267
# ================ Build the model ================
# Build the DeepConvLSTM model!
# Epoch: 1 cost time: 11.887876510620117
# VALI: Epoch: 1, Steps: 112 | Train Loss: 0.2793782  Vali Loss: 0.1946385 Vali Accuracy: 0.9177394  Vali weighted F1: 0.9038218  Vali macro F1 0.6978896
# Validation loss decreased (inf --> 0.194639).  Saving model ...
# Epoch: 2 cost time: 8.221569061279297
# VALI: Epoch: 2, Steps: 112 | Train Loss: 0.1911752  Vali Loss: 0.1620034 Vali Accuracy: 0.9268446  Vali weighted F1: 0.9249506  Vali macro F1 0.7872299
# new best score!!!!
# Validation loss decreased (0.194639 --> 0.162003).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 8.19191861152649
# VALI: Epoch: 3, Steps: 112 | Train Loss: 0.1697061  Vali Loss: 0.1502228 Vali Accuracy: 0.9331240  Vali weighted F1: 0.9288700  Vali macro F1 0.7918268
# new best score!!!!
# Validation loss decreased (0.162003 --> 0.150223).  Saving model ...
# new best score!!!!
# Epoch: 4 cost time: 8.195181369781494
# VALI: Epoch: 4, Steps: 112 | Train Loss: 0.1593601  Vali Loss: 0.1447519 Vali Accuracy: 0.9359498  Vali weighted F1: 0.9330792  Vali macro F1 0.8071196
# new best score!!!!
# Validation loss decreased (0.150223 --> 0.144752).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 8.209056615829468
# VALI: Epoch: 5, Steps: 112 | Train Loss: 0.1513778  Vali Loss: 0.1395285 Vali Accuracy: 0.9425432  Vali weighted F1: 0.9420126  Vali macro F1 0.8381345
# new best score!!!!
# Validation loss decreased (0.144752 --> 0.139529).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 8.215430736541748
# VALI: Epoch: 6, Steps: 112 | Train Loss: 0.1445744  Vali Loss: 0.1431956 Vali Accuracy: 0.9368917  Vali weighted F1: 0.9359364  Vali macro F1 0.8201661
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 7 cost time: 8.179234266281128
# VALI: Epoch: 7, Steps: 112 | Train Loss: 0.1425229  Vali Loss: 0.1401706 Vali Accuracy: 0.9328100  Vali weighted F1: 0.9359244  Vali macro F1 0.8316340
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 8 cost time: 8.150463342666626
# VALI: Epoch: 8, Steps: 112 | Train Loss: 0.1353246  Vali Loss: 0.1324013 Vali Accuracy: 0.9463108  Vali weighted F1: 0.9466409  Vali macro F1 0.8533139
# new best score!!!!
# Validation loss decreased (0.139529 --> 0.132401).  Saving model ...
# new best score!!!!
# Epoch: 9 cost time: 8.13549518585205
# VALI: Epoch: 9, Steps: 112 | Train Loss: 0.1320243  Vali Loss: 0.1296941 Vali Accuracy: 0.9469388  Vali weighted F1: 0.9462147  Vali macro F1 0.8492309
# new best score!!!!
# Validation loss decreased (0.132401 --> 0.129694).  Saving model ...
# new best score!!!!
# Epoch: 10 cost time: 8.136034965515137
# VALI: Epoch: 10, Steps: 112 | Train Loss: 0.1282008  Vali Loss: 0.1292728 Vali Accuracy: 0.9500785  Vali weighted F1: 0.9491723  Vali macro F1 0.8569176
# new best score!!!!
# Validation loss decreased (0.129694 --> 0.129273).  Saving model ...
# new best score!!!!
# Epoch: 11 cost time: 8.146188735961914
# VALI: Epoch: 11, Steps: 112 | Train Loss: 0.1258494  Vali Loss: 0.1315922 Vali Accuracy: 0.9450549  Vali weighted F1: 0.9451687  Vali macro F1 0.8486406
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 12 cost time: 8.10691785812378
# VALI: Epoch: 12, Steps: 112 | Train Loss: 0.1235992  Vali Loss: 0.1324782 Vali Accuracy: 0.9466248  Vali weighted F1: 0.9448579  Vali macro F1 0.8426614
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 13 cost time: 8.094650506973267
# VALI: Epoch: 13, Steps: 112 | Train Loss: 0.1213468  Vali Loss: 0.1283676 Vali Accuracy: 0.9453689  Vali weighted F1: 0.9463797  Vali macro F1 0.8545027
# new best score!!!!
# Validation loss decreased (0.129273 --> 0.128368).  Saving model ...
# new best score!!!!
# Epoch: 14 cost time: 8.133275747299194
# VALI: Epoch: 14, Steps: 112 | Train Loss: 0.1171530  Vali Loss: 0.1282301 Vali Accuracy: 0.9456829  Vali weighted F1: 0.9463756  Vali macro F1 0.8535943
# new best score!!!!
# Validation loss decreased (0.128368 --> 0.128230).  Saving model ...
# new best score!!!!
# Epoch: 15 cost time: 8.137420892715454
# VALI: Epoch: 15, Steps: 112 | Train Loss: 0.1158007  Vali Loss: 0.1253412 Vali Accuracy: 0.9472527  Vali weighted F1: 0.9484905  Vali macro F1 0.8609873
# new best score!!!!
# Validation loss decreased (0.128230 --> 0.125341).  Saving model ...
# new best score!!!!
# Epoch: 16 cost time: 8.175830125808716
# VALI: Epoch: 16, Steps: 112 | Train Loss: 0.1143977  Vali Loss: 0.1209152 Vali Accuracy: 0.9491366  Vali weighted F1: 0.9487772  Vali macro F1 0.8573171
# new best score!!!!
# Validation loss decreased (0.125341 --> 0.120915).  Saving model ...
# new best score!!!!
# Epoch: 17 cost time: 8.143107891082764
# VALI: Epoch: 17, Steps: 112 | Train Loss: 0.1126444  Vali Loss: 0.1252227 Vali Accuracy: 0.9510204  Vali weighted F1: 0.9504607  Vali macro F1 0.8614253
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 18 cost time: 8.103716611862183
# VALI: Epoch: 18, Steps: 112 | Train Loss: 0.1086488  Vali Loss: 0.1270530 Vali Accuracy: 0.9453689  Vali weighted F1: 0.9464482  Vali macro F1 0.8548861
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 19 cost time: 8.108935356140137
# VALI: Epoch: 19, Steps: 112 | Train Loss: 0.1057229  Vali Loss: 0.1305095 Vali Accuracy: 0.9450549  Vali weighted F1: 0.9438043  Vali macro F1 0.8411335
# EarlyStopping counter: 3 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 20 cost time: 8.117619752883911
# VALI: Epoch: 20, Steps: 112 | Train Loss: 0.1057888  Vali Loss: 0.1326695 Vali Accuracy: 0.9431711  Vali weighted F1: 0.9447452  Vali macro F1 0.8515829
# EarlyStopping counter: 4 out of 15
# Learning rate adjusting counter: 4 out of 5
# Epoch: 21 cost time: 8.143729448318481
# VALI: Epoch: 21, Steps: 112 | Train Loss: 0.1012678  Vali Loss: 0.1268538 Vali Accuracy: 0.9500785  Vali weighted F1: 0.9501131  Vali macro F1 0.8620983
# EarlyStopping counter: 5 out of 15
# Learning rate adjusting counter: 5 out of 5
# Updating learning rate to 0.0001
# Epoch: 22 cost time: 8.098331212997437
# VALI: Epoch: 22, Steps: 112 | Train Loss: 0.0918899  Vali Loss: 0.1260788 Vali Accuracy: 0.9503925  Vali weighted F1: 0.9510572  Vali macro F1 0.8664677
# EarlyStopping counter: 6 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 23 cost time: 8.104157209396362
# VALI: Epoch: 23, Steps: 112 | Train Loss: 0.0887224  Vali Loss: 0.1223224 Vali Accuracy: 0.9510204  Vali weighted F1: 0.9511554  Vali macro F1 0.8652599
# EarlyStopping counter: 7 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 24 cost time: 8.133299589157104
# VALI: Epoch: 24, Steps: 112 | Train Loss: 0.0875246  Vali Loss: 0.1229071 Vali Accuracy: 0.9513344  Vali weighted F1: 0.9515018  Vali macro F1 0.8663078
# EarlyStopping counter: 8 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 25 cost time: 8.14839220046997
# VALI: Epoch: 25, Steps: 112 | Train Loss: 0.0865563  Vali Loss: 0.1230618 Vali Accuracy: 0.9497645  Vali weighted F1: 0.9501070  Vali macro F1 0.8629371
# EarlyStopping counter: 9 out of 15
# Learning rate adjusting counter: 4 out of 5
# Epoch: 26 cost time: 8.137094259262085
# VALI: Epoch: 26, Steps: 112 | Train Loss: 0.0856339  Vali Loss: 0.1225952 Vali Accuracy: 0.9491366  Vali weighted F1: 0.9495513  Vali macro F1 0.8616011
# EarlyStopping counter: 10 out of 15
# Learning rate adjusting counter: 5 out of 5
# Updating learning rate to 1e-05
# Epoch: 27 cost time: 8.108508586883545
# VALI: Epoch: 27, Steps: 112 | Train Loss: 0.0838234  Vali Loss: 0.1222851 Vali Accuracy: 0.9497645  Vali weighted F1: 0.9501070  Vali macro F1 0.8629371
# EarlyStopping counter: 11 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 28 cost time: 8.110321760177612
# VALI: Epoch: 28, Steps: 112 | Train Loss: 0.0834217  Vali Loss: 0.1224476 Vali Accuracy: 0.9500785  Vali weighted F1: 0.9503854  Vali macro F1 0.8636077
# EarlyStopping counter: 12 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 29 cost time: 8.116501092910767
# VALI: Epoch: 29, Steps: 112 | Train Loss: 0.0831627  Vali Loss: 0.1223465 Vali Accuracy: 0.9500785  Vali weighted F1: 0.9503854  Vali macro F1 0.8636077
# EarlyStopping counter: 13 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 30 cost time: 8.126168727874756
# VALI: Epoch: 30, Steps: 112 | Train Loss: 0.0828430  Vali Loss: 0.1224988 Vali Accuracy: 0.9500785  Vali weighted F1: 0.9504522  Vali macro F1 0.8639792
# EarlyStopping counter: 14 out of 15
# Learning rate adjusting counter: 4 out of 5
# Epoch: 31 cost time: 8.153926372528076
# VALI: Epoch: 31, Steps: 112 | Train Loss: 0.0838810  Vali Loss: 0.1227115 Vali Accuracy: 0.9497645  Vali weighted F1: 0.9501741  Vali macro F1 0.8633097
# EarlyStopping counter: 15 out of 15
# Early stopping
# Loading the best validation model!
# Final Test Performance : Test Accuracy: 0.9442443  Test weighted F1: 0.9365492  Test macro F1 0.6577157
# ================ the 1 th CV Experiment ================
# Leave one Out Experiment : The 2 Part as the test
# [-] Target sampling weights:  [3.73636228e-05 3.60490267e-04]
# Train data number :  29538
# The number of classes is :  2
# The input_length  is :  64
# The channel_in is :  9
# Validation data number :  3282
# Test data number :  15093
# ================ Build the model ================
# Build the DeepConvLSTM model!
# Epoch: 1 cost time: 8.476221799850464
# VALI: Epoch: 1, Steps: 116 | Train Loss: 0.2760088  Vali Loss: 0.2189702 Vali Accuracy: 0.9064595  Vali weighted F1: 0.9044377  Vali macro F1 0.7196888
# Validation loss decreased (inf --> 0.218970).  Saving model ...
# Epoch: 2 cost time: 8.472681999206543
# VALI: Epoch: 2, Steps: 116 | Train Loss: 0.1886678  Vali Loss: 0.1687872 Vali Accuracy: 0.9274832  Vali weighted F1: 0.9151516  Vali macro F1 0.7229224
# new best score!!!!
# Validation loss decreased (0.218970 --> 0.168787).  Saving model ...
# new best score!!!!
# Epoch: 3 cost time: 8.485921621322632
# VALI: Epoch: 3, Steps: 116 | Train Loss: 0.1697473  Vali Loss: 0.1793529 Vali Accuracy: 0.9171237  Vali weighted F1: 0.9215644  Vali macro F1 0.7878394
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 4 cost time: 8.49581265449524
# VALI: Epoch: 4, Steps: 116 | Train Loss: 0.1604383  Vali Loss: 0.1524335 Vali Accuracy: 0.9283973  Vali weighted F1: 0.9314199  Vali macro F1 0.8118686
# new best score!!!!
# Validation loss decreased (0.168787 --> 0.152433).  Saving model ...
# new best score!!!!
# Epoch: 5 cost time: 8.45979642868042
# VALI: Epoch: 5, Steps: 116 | Train Loss: 0.1498167  Vali Loss: 0.1475847 Vali Accuracy: 0.9357099  Vali weighted F1: 0.9380574  Vali macro F1 0.8289221
# new best score!!!!
# Validation loss decreased (0.152433 --> 0.147585).  Saving model ...
# new best score!!!!
# Epoch: 6 cost time: 8.448051691055298
# VALI: Epoch: 6, Steps: 116 | Train Loss: 0.1442135  Vali Loss: 0.1559040 Vali Accuracy: 0.9357099  Vali weighted F1: 0.9288855  Vali macro F1 0.7769118
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 7 cost time: 8.446846008300781
# VALI: Epoch: 7, Steps: 116 | Train Loss: 0.1416971  Vali Loss: 0.1287490 Vali Accuracy: 0.9439366  Vali weighted F1: 0.9433676  Vali macro F1 0.8356601
# new best score!!!!
# Validation loss decreased (0.147585 --> 0.128749).  Saving model ...
# new best score!!!!
# Epoch: 8 cost time: 8.445735216140747
# VALI: Epoch: 8, Steps: 116 | Train Loss: 0.1341629  Vali Loss: 0.1324261 Vali Accuracy: 0.9408897  Vali weighted F1: 0.9400232  Vali macro F1 0.8252062
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 9 cost time: 8.486750841140747
# VALI: Epoch: 9, Steps: 116 | Train Loss: 0.1316376  Vali Loss: 0.1289197 Vali Accuracy: 0.9424132  Vali weighted F1: 0.9420408  Vali macro F1 0.8324082
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 10 cost time: 8.432634592056274
# VALI: Epoch: 10, Steps: 116 | Train Loss: 0.1275107  Vali Loss: 0.1317437 Vali Accuracy: 0.9427179  Vali weighted F1: 0.9398988  Vali macro F1 0.8194054
# EarlyStopping counter: 3 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 11 cost time: 8.431349754333496
# VALI: Epoch: 11, Steps: 116 | Train Loss: 0.1253810  Vali Loss: 0.1231778 Vali Accuracy: 0.9433272  Vali weighted F1: 0.9430021  Vali macro F1 0.8353050
# new best score!!!!
# Validation loss decreased (0.128749 --> 0.123178).  Saving model ...
# new best score!!!!
# Epoch: 12 cost time: 8.478216886520386
# VALI: Epoch: 12, Steps: 116 | Train Loss: 0.1227759  Vali Loss: 0.1276341 Vali Accuracy: 0.9408897  Vali weighted F1: 0.9428053  Vali macro F1 0.8412803
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 13 cost time: 8.466315507888794
# VALI: Epoch: 13, Steps: 116 | Train Loss: 0.1208599  Vali Loss: 0.1258420 Vali Accuracy: 0.9418038  Vali weighted F1: 0.9412563  Vali macro F1 0.8296550
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 14 cost time: 8.461781024932861
# VALI: Epoch: 14, Steps: 116 | Train Loss: 0.1173137  Vali Loss: 0.1209692 Vali Accuracy: 0.9427179  Vali weighted F1: 0.9430372  Vali macro F1 0.8372573
# new best score!!!!
# Validation loss decreased (0.123178 --> 0.120969).  Saving model ...
# new best score!!!!
# Epoch: 15 cost time: 8.465535163879395
# VALI: Epoch: 15, Steps: 116 | Train Loss: 0.1161610  Vali Loss: 0.1244223 Vali Accuracy: 0.9427179  Vali weighted F1: 0.9424723  Vali macro F1 0.8340100
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 16 cost time: 8.445178031921387
# VALI: Epoch: 16, Steps: 116 | Train Loss: 0.1120278  Vali Loss: 0.1212275 Vali Accuracy: 0.9424132  Vali weighted F1: 0.9421246  Vali macro F1 0.8328882
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 17 cost time: 8.465465545654297
# VALI: Epoch: 17, Steps: 116 | Train Loss: 0.1112303  Vali Loss: 0.1227821 Vali Accuracy: 0.9463742  Vali weighted F1: 0.9449163  Vali macro F1 0.8376037
# EarlyStopping counter: 3 out of 15
# Learning rate adjusting counter: 3 out of 5
# Epoch: 18 cost time: 8.436500549316406
# VALI: Epoch: 18, Steps: 116 | Train Loss: 0.1053279  Vali Loss: 0.1213703 Vali Accuracy: 0.9427179  Vali weighted F1: 0.9437235  Vali macro F1 0.8412268
# EarlyStopping counter: 4 out of 15
# Learning rate adjusting counter: 4 out of 5
# Epoch: 19 cost time: 8.505585432052612
# VALI: Epoch: 19, Steps: 116 | Train Loss: 0.1030884  Vali Loss: 0.1193951 Vali Accuracy: 0.9433272  Vali weighted F1: 0.9442488  Vali macro F1 0.8424903
# new best score!!!!
# Validation loss decreased (0.120969 --> 0.119395).  Saving model ...
# new best score!!!!
# Epoch: 20 cost time: 8.45609450340271
# VALI: Epoch: 20, Steps: 116 | Train Loss: 0.1022338  Vali Loss: 0.1352502 Vali Accuracy: 0.9414991  Vali weighted F1: 0.9416633  Vali macro F1 0.8328623
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 21 cost time: 8.460308313369751
# VALI: Epoch: 21, Steps: 116 | Train Loss: 0.1016217  Vali Loss: 0.1191960 Vali Accuracy: 0.9448507  Vali weighted F1: 0.9462027  Vali macro F1 0.8493715
# new best score!!!!
# Validation loss decreased (0.119395 --> 0.119196).  Saving model ...
# new best score!!!!
# Epoch: 22 cost time: 8.474622249603271
# VALI: Epoch: 22, Steps: 116 | Train Loss: 0.1009059  Vali Loss: 0.1135555 Vali Accuracy: 0.9488117  Vali weighted F1: 0.9485923  Vali macro F1 0.8516685
# new best score!!!!
# Validation loss decreased (0.119196 --> 0.113556).  Saving model ...
# new best score!!!!
# Epoch: 23 cost time: 8.438223123550415
# VALI: Epoch: 23, Steps: 116 | Train Loss: 0.0980282  Vali Loss: 0.1129411 Vali Accuracy: 0.9482023  Vali weighted F1: 0.9493752  Vali macro F1 0.8579607
# new best score!!!!
# Validation loss decreased (0.113556 --> 0.112941).  Saving model ...
# new best score!!!!
# Epoch: 24 cost time: 8.51365613937378
# VALI: Epoch: 24, Steps: 116 | Train Loss: 0.0939012  Vali Loss: 0.1155368 Vali Accuracy: 0.9494211  Vali weighted F1: 0.9503740  Vali macro F1 0.8601842
# EarlyStopping counter: 1 out of 15
# Learning rate adjusting counter: 1 out of 5
# Epoch: 25 cost time: 8.435785293579102
# VALI: Epoch: 25, Steps: 116 | Train Loss: 0.0931231  Vali Loss: 0.1209187 Vali Accuracy: 0.9454601  Vali weighted F1: 0.9455751  Vali macro F1 0.8439598
# EarlyStopping counter: 2 out of 15
# Learning rate adjusting counter: 2 out of 5
# Epoch: 26 cost time: 8.447922468185425
# VALI: Epoch: 26, Steps: 116 | Train Loss: 0.0926036  Vali Loss: 0.1207896 Vali Accuracy: 0.9451554  Vali weighted F1: 0.9459758  Vali macro F1 0.8471569
# EarlyStopping counter: 3 out of 15
# Learning rate adjusting counter: 3 out of 5
